# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://rekrutmenbersama.fhcibumn.id/job"

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
page = BeautifulSoup(response.content, "html.parser")

# %%
page
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- Title Of Site -->
# <!-- HTML Meta Tags -->
# <title>Rekrutmen Bersama BUMN 2022</title>
# <meta content="Rekrutmen Bersama BUMN 2022" name="description"/>
# <!-- Google / Search Engine Tags -->
# <meta content="Rekrutmen Bersama BUMN 2022" itemprop="name"/>
# <meta content="Rekrutmen Bersama BUMN 2022" itemprop="description"/>
# <meta content="https://rekrutmenbersama.fhcibumn.id/assets/frontend/images/fav-icon.png" itemprop="image"/>
# <!-- Fav and Touch Icons -->
# <link href="https://rekrutmenbersama.fhcibumn.id/assets/frontend/images/fav-icon.ico" rel="icon" type="image/x-icon"/>
# <!-- Twitter Meta Tags -->
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Rekrutmen Bersama BUMN 2022" name="twitter:title"/>
# <meta content="Rekrutmen Bersama BUMN 2022" name="twitter:description"/>
# <meta content="https://rekrutmenbersama.fhcibumn.id/assets/frontend/images/fav-icon.png" name="twitter:image"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="753706387582-f8vvkeidc89og4ih9a91ushmsih52d3h.apps.googleusercontent.com" name="google-signin-client_id"/>
# <link href="https://rekrutmenbersama.fhcibumn.id/assets/backend/vendors/font-awesome/css/font-awesome.min.css" rel="stylesheet"/>
# <meta content="#da532c" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# <!-- CSS Plugins -->
# <link href="https://rekrutmenbersama.fhcibumn.id/assets/loading.css" rel="stylesheet" type="text/css"/>
# <link crossorigin="anonymous" href="https://rekrutmenbersama.fhcibumn.id/assets/frontend/bootstrap4/bootstrap.min.css" rel="stylesheet"/>
# <link href="https://rekrutmenbersama.fhcibumn.id/assets/frontend/plugins/toastr/toastr.min.css" rel="stylesheet"/>
# <!-- CSS Custom -->
# <link href="https://rekrutmenbersama.fhcibumn.id/assets/frontend/css/style.css" rel="stylesheet"/>
# <link href="https://rekrutmenbersama.fhcibumn.id/assets/backend/vendors/nprogress/nprogress.css" rel="stylesheet" type="text/css"/>
# <link href="https://rekrutmenbersama.fhcibumn.id/assets/backend/vendors/bootstrap-sweetalert/dist/sweetalert.css" rel="stylesheet" type="text/css"/>
# <link href="https://rekrutmenbersama.fhcibumn.id/assets/frontend/animsition/animsition.css" rel="stylesheet" type="text/css">
# </link></head>
# <style media="screen">
#
#   .form-control-error{
#     color: red;
#   }
#   .text-green{
#     color:#0093AD;
#   }
#   .text-dark-blue{
#     color:#0093AD;
#   }
#   .text-grey{
#     color: #828487 !important;
#   }
#   .text-red{
#     color:red;
#   }
#
#   @font-face {
#       font-family: 'Material Icons';
#       font-style: normal;
#       font-weight: 400;
#       src: local('Material Icons'), local('MaterialIcons-Regular'), url(https://rekrutmenbersama.fhcibumn.id/assets/frontend/fonts/google-material-icon.woff2) format('woff2');
#   }
#   .material-icons {
#       font-family: 'Material Icons';
#       font-weight: normal;
#       font-style: normal;
#       font-size: 24px;
#       line-height: 1;
#       letter-spacing: normal;
#       text-transform: none;
#       display: inline-block;
#       white-space: nowrap;
#       word-wrap: normal;
#       direction: ltr;
#       -moz-font-feature-settings: 'liga';
#       -moz-osx-font-smoothing: grayscale;
#   }
#   @font-face {
#     font-family: 'Rubik-Bold';
#     font-style: normal;
#     src: local('Rubik'), url(https://rekrutmenbersama.fhcibumn.id/assets/font/rubik/Rubik-SemiBold.ttf) format('truetype');
#   }
#   @font-face {
#     font-family: 'Rubik';
#     font-style: normal;
#     font-weight: 300;
#     src: local('Rubik'), url(https://rekrutmenbersama.fhcibumn.id/assets/font/rubik/Rubik-Regular.ttf) format('truetype');
#   }
#   .text-bold{
#     font-family: 'Rubik-Bold' !important;
#   }
#   body {
#     font-family: 'Rubik',sans-serif !important;
#   }
#   h1, h3, h3, h4 , h5{
#     font-family: 'Rubik-Bold' !important;
#   }
#   .modal-header{
#       border-bottom:unset !important;
#   }
#   .modal-footer{
#       background:#007afe;
#       border-top:unset;
#       border-bottom-left-radius :0.5rem;
#       border-bottom-right-radius :0.5rem;
#   }
#   .modal-content{
#       border:unset;
#       box-shadow:0 6px 15px rgba(68, 69, 71, 0.66);
#       border-radius:0.5rem;
#   }
#   .modal-title{
#     font-weight:bold;
#   }
#   .form-control-error ul{
#     margin-left: -20px;
#   }
#   .close .material-icons {
#   	font-size: 33px;
#   	color: #b70000;
#   }
#   .navbar-light .navbar-nav .nav-link{
#     /* color: #565656 !important; */
#     font-weight: bold;
#   }
#   .btn-info{
#     background: #335eea;
#     box-shadow: 0 .5rem 1.5rem rgba(22,28,45,.1) !important;
#   }
#   @media (min-width: 768px) {
#     .navbar-brand.abs
#         {
#             position: absolute;
#             width: 100%;
#             left: 0;
#             text-align: center;
#         }
#     }
#   .nav.navbar-nav{
#     text-align: left;
#   }
#   .nav.navbar-nav li{
#     padding: 8px 0px 8px 0px;
#   }
#   .section-custom{
#     padding: 20px;
#   }
#   .center-item{
#     position: absolute;
#     top: 50%;
#     left: 50%;
#     -moz-transform: translateX(-50%) translateY(-50%);
#     -webkit-transform: translateX(-50%) translateY(-50%);
#     transform: translateX(-50%) translateY(-50%);
#   }
#   .m-b-0{
#     margin-bottom: 0px;
#   }
#   .m-t-20{
#     margin-top: 20px;
#   }
#   .icon-big{
#     font-size: 20px !important;
#   }
#   .navbar-expand-lg > .container, .navbar-expand-lg > .container-fluid{
#     padding-left: 10px;
#     padding-right: 10px;
#   }
#   .badge-blue{
#     background: #c2d5ff;color: #007bff;padding: 10px;border-radius: 5px;
#   }
#   .small-badge-blue {
#   	background: #c2d5ff;
#   	color: #007bff;
#   	padding: 5px;
#   	border-radius: 5px;
#   	font-size: 12px;
#   	font-weight: bold;
#   }
#
#   .navbar.scrolled {
#     background-color: red !important;
#     transition: background-color 200ms linear;
#     box-shadow:0 4px 24px 0 rgba(141, 13, 13, 0.26),0 12px 64px 0 rgba(152, 27, 27, 0.1);
#   }
#   /* .navbar.scrolled .nav-link {
#     color:white !important;
#   } */
#   .bar1, .bar2, .bar3 {
#     width: 25px;
#     height: 3px;
#     background-color: white;
#     margin: 6px 0;
#     transition: 0.4s;
#   }
#
#   .change .bar1 {
#     -webkit-transform: rotate(-45deg) translate(-9px, 6px);
#     transform: rotate(-45deg) translate(-5px, 4px);
#   }
#
#   .change .bar2 {opacity: 0;}
#
#   .change .bar3 {
#     -webkit-transform: rotate(45deg) translate(-8px, -8px);
#     transform: rotate(45deg) translate(-8px, -8px);
#   }
#   .nav-tabs-custom {
#     display: flex;
#     flex-flow: column nowrap;
#     align-items: flex-start;
#   }
#   .nav-tabs-custom > li {
#     -webkit-writing-mode: vertical-lr;
#         -ms-writing-mode: tb-lr;
#             writing-mode: vertical-lr;
#     -webkit-transform: rotate(180deg);
#             transform: rotate(180deg);
#     -webkit-transform-origin: center center;
#             transform-origin: center center;
#     list-style-type: none;
#   }
#   .nav-tabs-custom > li > label {
#     display: block;
#     padding: 0.5rem;
#     /* color:white; */
#   }
#   .nav-tabs-custom > li > a {
#     display: block;
#     padding: 0.5rem;
#     color:black;
#   }
#   .navbar-collapse.collapse.show{
#       background:#00000087;
#   }
#   .navbar-light .navbar-nav .nav-link{
#       /* color:white !important; */
#       font-weight:bold;
#   }
#
#   @media (max-width: 768px) {
#     .responsive-media {
#       padding: 10px 20px 10px 20px !important;
#     }
#   }
#
#   @media (min-width: 768px) {
#     .section-left-banner{
#       padding: 20px !important;
#     }
#   }
#
#   @media (max-width: 576px) {
#     .title-banner {
#       font-size: 2rem !important;
#     }
#     .desc-banner {
#       font-size: 1rem !important;
#     }
#     .img-logo{
#       /* width: 100px !important; */
#     }
#     .section-card{
#       padding: 20px;
#     }
#     .responsive-media-body{
#       padding: 100px 30px 100px 30px !important;
#     }
#   }
#   .text-blue{
#     color:#1C2855;
#   }
#   .text-primary{
#     color: #0097b1 !important;
#   }
#
#   .circle-element{
#     position: absolute;
#     z-index: 1;
#     background-color: white;
#     border-radius: 100%;
#   }
#   @media (min-width: 769px) {
#     /* desktop */
#     .custom-px-5, .custom-p-5{
#       padding-left: 5rem !important;
#       padding-right: 5rem !important;
#     }
#     .custom-py-5, .custom-p-5{
#       padding-top: 5rem !important;
#       padding-bottom: 5rem !important;
#     }
#   }
#   @media (max-width: 768px) {
#     /* mobile */
#     .custom-px-5, .custom-p-5{
#       padding-left: .125rem !important;
#       padding-right: .125rem !important;
#     }
#     .custom-py-5, .custom-p-5{
#       padding-top: .125rem !important;
#       padding-bottom: .125rem !important;
#     }
#     .circle-element{
#       display: none !important;
#     }
#   }
# </style>
# <style>
#
#
#               .loading_tg {
#                   position: absolute;
#                   width: 100%;
#                   height: 100%;
#                   z-index: 1000;
#                   background-color: #fff;
#
#               }
#
#               .msg {
#                   color: #6c6c6c;
#                   font: 20px/20px Arial, sans-serif;
#                   letter-spacing: .2px;
#                   text-align: center
#               }
#
#
#               .invfr {
#                   position: absolute;
#                   left: 0;
#                   top: 0;
#                   z-index: -1;
#                   width: 0;
#                   height: 0;
#                   border: 0
#               }
#
#               .msgb {
#                   position: absolute;
#                   right: 0;
#                   font-size: 12px;
#                   font-weight: normal;
#                   color: #000;
#                   padding: 20px
#               }
#               #logo {
#                   animation: a-s .5s 1.5s 1 forwards;
#                   height: 4px;
#                   margin: 56px auto 20px;
#                   opacity: 0;
#                   overflow: hidden;
#                   position: relative;
#                   width: 300px
#               }
#
#
#               #loadingProgressG {
#                   animation: a-s .5s 1.5s 1 forwards;
#                   height: 4px;
#                   margin: 56px auto 20px;
#                   opacity: 0;
#                   overflow: hidden;
#                   position: relative;
#                   width: 300px
#               }
#
#               #loadingProgressG::before {
#                   animation: a-lb 20s 3s linear forwards;
#                   content: '';
#                   display: block;
#                   height: 100%;
#                   position: absolute;
#                   transform: translateX(-300px);
#                   width: 100%
#               }
#
#
#
#               #loadingProgressG{
#                   width:352px;
#                   height:5px;
#                   overflow:hidden;
#                   background-color:#219BA8;
#                   margin:auto;
#                   border-radius:14px;
#                       -o-border-radius:14px;
#                       -ms-border-radius:14px;
#                       -webkit-border-radius:14px;
#                       -moz-border-radius:14px;
#               }
#
#               .loadingProgressG{
#                   background-color:#219BA8;
#                   margin-top:0;
#                   margin-left:-352px;
#                   animation-name:bounce_loadingProgressG;
#                       -o-animation-name:bounce_loadingProgressG;
#                       -ms-animation-name:bounce_loadingProgressG;
#                       -webkit-animation-name:bounce_loadingProgressG;
#                       -moz-animation-name:bounce_loadingProgressG;
#                   animation-duration:2.08s;
#                       -o-animation-duration:2.08s;
#                       -ms-animation-duration:2.08s;
#                       -webkit-animation-duration:2.08s;
#                       -moz-animation-duration:2.08s;
#                   animation-iteration-count:infinite;
#                       -o-animation-iteration-count:infinite;
#                       -ms-animation-iteration-count:infinite;
#                       -webkit-animation-iteration-count:infinite;
#                       -moz-animation-iteration-count:infinite;
#                   animation-timing-function:linear;
#                       -o-animation-timing-function:linear;
#                       -ms-animation-timing-function:linear;
#                       -webkit-animation-timing-function:linear;
#                       -moz-animation-timing-function:linear;
#                   width:352px;
#                   height:28px;
#               }
#
#
#
#               @keyframes bounce_loadingProgressG{
#                   0%{
#                       margin-left:-352px;
#                   }
#
#                   100%{
#                       margin-left:352px;
#                   }
#               }
#
#               @-o-keyframes bounce_loadingProgressG{
#                   0%{
#                       margin-left:-352px;
#                   }
#
#                   100%{
#                       margin-left:352px;
#                   }
#               }
#
#               @-ms-keyframes bounce_loadingProgressG{
#                   0%{
#                       margin-left:-352px;
#                   }
#
#                   100%{
#                       margin-left:352px;
#                   }
#               }
#
#               @-webkit-keyframes bounce_loadingProgressG{
#                   0%{
#                       margin-left:-352px;
#                   }
#
#                   100%{
#                       margin-left:352px;
#                   }
#               }
#
#               @-moz-keyframes bounce_loadingProgressG{
#                   0%{
#                       margin-left:-352px;
#                   }
#
#                   100%{
#                       margin-left:352px;
#                   }
#               }
#
#
#
#               @keyframes a-s {
#                   100% {
#                       opacity: 1
#                   }
#               }
#
#               @keyframes a-h {
#                   100% {
#                       opacity: 0
#                   }
#               }
#
#               @keyframes a-nt {
#                   100% {
#                       transform: none
#                   }
#               }
#
#               @keyframes a-e {
#                   43% {
#                       animation-timing-function: cubic-bezier(.8, 0, .2, 1);
#                       transform: scale(.75)
#                   }
#                   60% {
#                       animation-timing-function: cubic-bezier(.8, 0, 1, 1);
#                       transform: translateY(-16px)
#                   }
#                   77% {
#                       animation-timing-function: cubic-bezier(.16, 0, .2, 1);
#                       transform: none
#                   }
#                   89% {
#                       animation-timing-function: cubic-bezier(.8, 0, 1, 1);
#                       transform: translateY(-5px)
#                   }
#                   100% {
#                       transform: none
#                   }
#               }
#
#               @keyframes a-ef {
#                   24% {
#                       animation-timing-function: cubic-bezier(.8, 0, .6, 1);
#                       transform: scaleY(.42)
#                   }
#                   52% {
#                       animation-timing-function: cubic-bezier(.63, 0, .2, 1);
#                       transform: scaleY(.98)
#                   }
#                   83% {
#                       animation-timing-function: cubic-bezier(.8, 0, .84, 1);
#                       transform: scaleY(.96)
#                   }
#                   100% {
#                       transform: none
#                   }
#               }
#
#               @keyframes a-efs {
#                   24% {
#                       animation-timing-function: cubic-bezier(.8, 0, .6, 1);
#                       opacity: .3
#                   }
#                   52% {
#                       animation-timing-function: cubic-bezier(.63, 0, .2, 1);
#                       opacity: .03
#                   }
#                   83% {
#                       animation-timing-function: cubic-bezier(.8, 0, .84, 1);
#                       opacity: .05
#                   }
#                   100% {
#                       opacity: 0
#                   }
#               }
#
#               @keyframes a-es {
#                   24% {
#                       animation-timing-function: cubic-bezier(.8, 0, .6, 1);
#                       transform: rotate(-25deg)
#                   }
#                   52% {
#                       animation-timing-function: cubic-bezier(.63, 0, .2, 1);
#                       transform: rotate(-42.5deg)
#                   }
#                   83% {
#                       animation-timing-function: cubic-bezier(.8, 0, .84, 1);
#                       transform: rotate(-42deg)
#                   }
#                   100% {
#                       transform: rotate(-43deg)
#                   }
#               }
#
#   </style>
# <script src="https://rekrutmenbersama.fhcibumn.id/assets/frontend/js/jquery.min.js" type="text/javascript"></script>
# <script src="https://rekrutmenbersama.fhcibumn.id/assets/frontend/animsition/animsition.js"></script>
# <style media="screen">
#   @media (min-width: 769px) {
#     .section-content-utama{
#       margin: 0;position: absolute;top: 50%;-ms-transform: translateY(-50%);transform: translateY(-50%);
#     }
#     .section-content-kedua{
#       padding: 10px 70px;
#     }
#   }
#   @media (max-width: 768px) {
#     .logo-left{
#       display: none;
#     }
#     .section-content-kedua{
#       padding: 10px 0px;
#     }
#   }
# </style>
# <body>
# <div class="loading_tg">
# <div style="bottom:0;left:0;overflow:hidden;position:absolute;right:0;top:0">
# <div style="animation:a-h .5s 1.25s 1 linear forwards,a-nt .6s 1.25s 1 cubic-bezier(0,0,.2,1);background:#eee;border-radius:50%;height:800px;left:50%;margin:-448px -400px 0;position:absolute;top:50%;transform:scale(0);width:800px">
# </div>
# </div>
# <div style="height:100%;text-align:center;position: relative;top: 35%;">
# <div id="logo" style="height:128px;margin:0 auto;position:relative;width:300px;background-image: url(https://rekrutmenbersama.fhcibumn.id/assets/frontend/images/rekrutmen_bersama_bumn.svg);background-size: contain;background-repeat: no-repeat;background-position: center;">
# </div>
# <div id="loadingProgressG">
# <div class="loadingProgressG" id="loadingProgressG_1"></div>
# </div>
# <div class="msg" style="animation:a-s .25s 1.25s 1 forwards;opacity:0;margin-top: 20px;">Harap Tunggu…</div>
# </div>
# </div>
# <div class="container-fluid animsition" style="padding:0px">
# <style media="screen">
#   /* laptop */
#   @media (min-width: 768px) {
#     .navbar-style-home{
#       padding:15px 50px 0px;
#     }
#     .img-logo{
#       height:45px;
#     }
#     #navbar_top{
#       padding-left: 3rem;
#       padding-right: 3rem;
#     }
#     .nav-item.active {
#     	border-bottom: solid 3px #73c6d4;
#     }
#   }
#
#   /* phone */
#   @media (max-width: 768px) {
#     .navbar-style-home{
#       padding:15px 10px 0px;
#     }
#
#     #navbar_top{
#       padding-left: 0rem;
#       padding-right: 0rem;
#     }
#     .navbar-nav > li:hover > a, .navbar-nav > li.active > a {
#     	color: #0097b1 !important;
#       font-family: "Rubik-Bold";
#     }
#     .navbar-nav .nav-link {
#     	padding-right: 0;
#     	padding-left: 0;
#     	color: black;
#     }
#     .navbar-brand{
#       width: 80% !important;
#       margin-right: 0px !important;
#       padding: 0px 5px !important;
#     }
#     .navbar-toggler{
#       width: 20% !important;
#       padding-right: 0px !important;
#     }
#     .img-logo{
#       width: 25% !important;
#       height: auto !important;
#     }
#     #navbar_top{
#       margin-bottom: 30px ;
#     }
#   }
#
#   .hide-nav{
#     display: none;
#   }
#   .btn-rounded{
#     border-radius: 50px;
#   }
#   .btn-success {
#   	background-color: #0097b1;
#   	border-color: #0097b1;
#   }
#   .btn-success:hover {
#   	border-color: #0097b1 !important;
#     background: #0097b1 !important;
#   }
#
#   .navbar-light .navbar-nav .active > .nav-link{
#     font-weight: bold !important;
#   }
#   .navbar-light .navbar-nav .nav-link {
#   	color: black;
#     font-weight: normal !important;
#   }
#   .btn-outline-success {
#   	color: #0296af !important;
#   	border-color: #0094ad !important;
#   }
#   .btn-outline-success:hover {
#   	color: #0296af !important;
#   	border-color: #EEF5F6 !important;
#     background: #EEF5F6 !important;
#   }
#   .navbar-nav > li:hover > a, .navbar-nav > li.active > a {
#   	color: #0097b1 !important;
#   	background: transparent !important;
#   }
#   .nav-item {
#     	padding-left: 0.5rem;
#     	padding-right: 0.5rem;
#     	padding-top: 13px;
#     	padding-bottom: 13px;
#     }
#   .scrolled_nav{
#     box-shadow: 5px 12px 20px rgba(138, 138, 138, 0.13);
#   }
#
#
# </style>
# <nav class="navbar navbar-expand-lg navbar-light pt-0" id="navbar_top" style=" border-bottom: solid 0px #e6e6e6;min-height:10vh; z-index:1; position:sticky; top:0; z-index: 1000;width:100%; background:white">
# <a class="navbar-brand" href="https://rekrutmenbersama.fhcibumn.id/" style="">
# <img alt="" class="img-logo" height="60px" id="img_logo_top_bar" src="https://rekrutmenbersama.fhcibumn.id/assets/frontend/images/kbumn_logo.png"/>
# <img alt="" class="img-logo" id="" src="https://rekrutmenbersama.fhcibumn.id/assets/frontend/images/bumn.png" style=""/>
# <img alt="" class="img-logo" id="" src="https://rekrutmenbersama.fhcibumn.id/assets/frontend/images/rekrutmen_bersama_bumn.svg" style=""/>
# <img alt="" class="img-logo" id="" src="https://rekrutmenbersama.fhcibumn.id/assets/frontend/images/fhci.png" style=""/>
# </a>
# <button class="navbar-toggler" onclick="modal_show()" style="background:transparent; border:0px" type="button">
# <i class="material-icons" id="btn_collapse_navbar_top" style="font-size: 28px;color:white;background: #219BA8;border-radius: 5px;padding: 5px; border:0px">sort</i>
# </button>
# <div class="collapse navbar-collapse" id="navbarSupportedContent" style="border-radius: 5px;padding:0px 20px">
# <ul class="navbar-nav ml-auto pr-2" style="">
# <li class="nav-item nav_home active">
# <a class="nav-link" href="https://rekrutmenbersama.fhcibumn.id/">Home <span class="sr-only">(current)</span></a>
# </li>
# <li class="nav-item nav_bumn">
# <a class="nav-link" href="https://rekrutmenbersama.fhcibumn.id/bumn">Life at BUMN</a>
# </li>
# <li class="nav-item nav_job">
# <a class="nav-link" href="https://rekrutmenbersama.fhcibumn.id/job">Job Vacancies</a>
# </li>
# <li class="nav-item nav_faq">
# <a class="nav-link" href="https://rekrutmenbersama.fhcibumn.id/faq">FAQ</a>
# </li>
# </ul>
# <div style=" text-align:right;border-left: solid 1px #eee;padding-left: 2rem;">
# <a class="btn btn-outline-success btn-rounded pl-4 pr-4 btn-sm pt-2 pb-2" href="https://rekrutmenbersama.fhcibumn.id/register/register_page" style="margin-right:10px;font-size: smaller;">Register</a>
# <a class="btn btn-success btn-rounded pl-4 pr-4 btn-sm pt-2 pb-2" href="https://rekrutmenbersama.fhcibumn.id/login_page" style="margin-right:10px;font-size: smaller;">Login</a> </div>
# </div>
# </nav>
# <div class="modal" id="modal_menu">
# <div class="modal-dialog">
# <div class="modal-content">
# <!-- Modal Header -->
# <div class="modal-header">
# <h4 class="modal-title">Menu</h4>
# <button class="close" data-dismiss="modal" type="button"><i class="material-icons">clear</i></button>
# </div>
# <!-- Modal body -->
# <div class="modal-body">
# <div class="row">
# <div class="col-md-12">
# <ul class="navbar-nav ml-auto pr-2" style="">
# <li class="nav-item nav_home active">
# <a class="nav-link" href="https://rekrutmenbersama.fhcibumn.id/">Home <span class="sr-only">(current)</span></a>
# </li>
# <li class="nav-item nav_bumn">
# <a class="nav-link" href="https://rekrutmenbersama.fhcibumn.id/bumn">Life at BUMN</a>
# </li>
# <li class="nav-item nav_job">
# <a class="nav-link" href="https://rekrutmenbersama.fhcibumn.id/job">Job Vacancies</a>
# </li>
# <li class="nav-item nav_faq">
# <a class="nav-link" href="https://rekrutmenbersama.fhcibumn.id/faq">FAQ</a>
# </li>
# </ul>
# <div class="ml-auto my-3 my-sm-2 d-lg-block">
# <a class="btn btn-outline-success btn-rounded pl-4 pr-4 btn-sm pt-2 pb-2" href="https://rekrutmenbersama.fhcibumn.id/register/register_page" style="margin-right:10px;font-size: smaller;">Register</a>
# <a class="btn btn-success btn-rounded pl-4 pr-4 btn-sm pt-2 pb-2" href="https://rekrutmenbersama.fhcibumn.id/login_page" style="margin-right:10px;font-size: smaller;">Login</a> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="modal_off_pendaftaran" role="dialog">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <h4 class="modal-title">Informasi</h4>
# <button class="close" data-dismiss="modal" type="button">×</button>
# </div>
# <div class="modal-body">
# <p>Pendaftaran akan dibuka pada tanggal <b>14 - 25 April 2022</b></p>
# </div>
# <div class="modal-footer" style="background: #0097b1 !important;">
# <button class="btn btn-default" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# $(document).ready(function(){
#   $(".nav-item").removeClass('active');
#   if ('Job' == 'Home') {
#     $(".nav_home").addClass('active');
#   }
#   else if ('Job' == 'Bumn') {
#     $(".nav_bumn").addClass('active');
#   }
#   else if ('Job' == 'Job') {
#     $(".nav_job").addClass('active');
#   }
#   else if ('Job' == 'FAQ') {
#     $(".nav_faq").addClass('active');
#   }
# });
#
# function modal_show()
# {
#   $("#modal_menu").modal('show');
# }
#
# $(window).scroll(function() {
#     var nav = $('#navbar_top');
#     var top = 200;
#     if ($(window).scrollTop() >= top) {
#         nav.addClass('scrolled_nav');
#
#     } else {
#         nav.removeClass('scrolled_nav');
#     }
# });
#
# </script>
# <div style="padding:0px;width:100%">
# <script src="https://rekrutmenbersama.fhcibumn.id/assets/backend/js/list.min.js"></script>
# <style media="screen">
#     .cat__content{
#       background-color: white;
#     }
#     .card-list-vacancy{
#       background: white;border-radius: 10px;border: solid 1px #393939;
#     }
#
#     .card-list-vacancy:hover{
#       box-shadow: 0 6px 15px rgba(36, 37, 38, 0.08);
#       border: solid 1px #0097b1;
#     }
#
#     .card-list-vacancy-saved{
#       background: white;border-radius: 10px;border: solid 1px #393939;margin-bottom: 10px;
#     }
#     .card-list-vacancy-saved:hover{
#       box-shadow: 0 6px 15px rgba(36, 37, 38, 0.08);
#       border: solid 1px #0097b1;
#     }
#     .badge-blue{
#       background: #335eea;padding: 5px;border-radius: 5px;color: white;
#     }
#
#     .job_not_available {
#     	background: #d9dee1 !important;
#     }
#     /* desk */
#     @media (min-width: 769px) {
#       .cover-job{
#         padding-left: 35px !important; padding-right: 35px !important;
#       }
#       .cover-job-list{
#         padding-left: 35px !important; padding-right: 35px !important;
#       }
#       .center-list-job{
#         padding:5px 20px;
#       }
#       .hide-lg{
#         display: none;
#       }
#       .legend-list-child{
#         margin-right: 5px;
#       }
#       .style_landing_page{
#         padding: 4rem 3rem;
#       }
#       .sticky_img{
#         top: 7rem;
#       }
#     }
#
#     /* mobile */
#     @media (max-width: 768px) {
#       .hide-small{
#         display: none;
#       }
#       .hide-lg{
#         display: block;
#       }
#       .cover-job{
#           padding-left: 0px; padding-right: 0px;
#       }
#       .cover-job-list{
#         padding:10px !important;
#       }
#       .center-list-job{
#         padding:15px 5px;
#       }
#       .legend_list{
#         display: inherit !important;
#       }
#       .background-left {
#         position: absolute;
#         width: 100% !important;
#       }
#       .sticky_img{
#         top: 4.4rem;
#       }
#       #navbar_top{
#         margin-bottom: 0px !important ;
#       }
#     }
#     @media (max-width: 767px){
#       .sticky_img{
#         background-color: #D4E5E8;
#       }
#     }
#
#     .circle{
#       width: 8px;
#       height: 8px;
#       display: block;
#       background: #219BA8;
#       border-radius: 50%;
#       margin-top: auto;
#       margin-bottom: auto;
#       margin-left: 10px;
#       margin-right: 10px;
#     }
#     .select2-container .select2-selection--single{
#       height: 36px !important;
#     }
#     .select2-container--default .select2-selection--single .select2-selection__rendered{
#       line-height: 32px !important;
#     }
#     .select2-container--default .select2-selection--single .select2-selection__arrow{
#       height: 33px !important;
#     }
#     .container_sticky {
#       display: flex;
#       justify-content: space-around;
#       align-items: flex-start;
#       height: 100%;
#       }
#     .sticky_img{
#       z-index: 10;
#       position: sticky;
#     }
#     .color-grey{
#       color: grey;
#     }
# </style>
# <style media="screen">
#   ol li {
#     text-align: justify;
#   }
#   .nav-tabs-horizontal .nav-tabs .nav-item .nav-link.active, .nav-tabs-horizontal .nav-tabs .nav-item .nav-link:focus {
#     border-bottom-color: #3a93ad !important;
#   }
#   .nav-tabs .nav-item.show .nav-link, .nav-tabs .nav-link.active{
#     background-color: transparent !important;
#   }
#   .background-left {
#         position: absolute;
#         width: 500px;
#         height: 309px;
#         left: -87px;
#         top: -43px;
#         background: rgba(0, 147, 173, 0.37 );
#         filter: blur(150px);
#         z-index: 1;
#         border-radius: 50%;
#     }
#   .background-right {
#     position: absolute;
#     width: 859px;
#     height: 500px;
#     right: 0px;
#     bottom: -32px;
#     background: rgba(0, 147, 173, 0.18);
#     filter: blur(100px);
#     z-index: 1;
#     border-top-left-radius: 50%;
#   }
#   .pagination li{
#     padding: 5px;
#   }
#   .pagination li:hover{
#     background: whitesmoke !important;
#   }
#   .pagination .active {
#   	background: #33b6cb;
#   	border-radius: 5px;
#   }
#   .pagination > li > a, .pagination > li > span {
#   	color: black !important;
#   }
# </style>
# <style media="screen">
#   .no-result {
#     display:none;
#   }
#   .nav-link.nav-link-inside.active {
#   	background: #219ba8 !important;
#   	border-radius: 5px;
#   	color: white !important;
#   	border: 0px;
#   }
#   .nav-link.nav-link-inside {
#   	color: grey;
#   }
# </style>
# <div class="container-fluid p-0 m-0" style="min-height:50vh; display:grid">
# <div class="nav-tabs-horizontal" style="z-index:5">
# <div class="tab-content">
# <!-- <div class="col-md-12 m-0 mb-2 pl-0 pr-0">
#         <div class="tab-content">
#           <div class="text-center" for="" style="padding: 10px 15px;margin-bottom: 10px;background: #1C2855;/* border-radius: 5px; *//* display: flex; */" class="col-12">
#             <span class="my-auto text-white">&nbsp; Jelajahi minat dan kemampuan Anda dengan bergabung di berbagai klaster industri BUMN Indonesia yang berpartisipasi dalam Rekrutmen Bersama BUMN Tahun 2022</span>
#           </div>
#         </div>
#       </div> -->
# <div class="tab-pane active style_landing_page" id="home1" role="tabcard" style="">
# <div class="row m-0 container_sticky" id="users">
# <div class="col-md-3 px-0 sticky_img" style="">
# <div class="px-0 d-block d-md-none" id="filterPanel">
# <div class="row mr-0 px-3 py-2 active" id="headingFilter" style="background-color: #0093AD; color:white;">
# <div class="col my-auto">
# <h5 class="mb-0">Filter Vacancy</h5>
# </div>
# <div class="col px-0" id="btn-filter" style="max-width: fit-content;">
# <button aria-controls="collapseFilter" aria-expanded="true" class="btn text-white float-right d-flex content-align-betweens" data-target="#collapseFilter" data-toggle="collapse" style="background-color: #0093AD !important;">
#                       Hide <span class="material-icons">arrow_drop_up</span>
# </button>
# </div>
# </div>
# </div>
# <div aria-labelledby="headingFilter" class="collapse show" data-parent="#filterPanel" id="collapseFilter">
# <div class="filter-group px-2 pt-3 row mr-0">
# <div class="form-group col-sm-12">
# <small for="exampleFormControlSelect1">Cari Posisi</small>
# <input class="search form-control" placeholder="Search" type="text"/>
# </div>
# <div class="form-group col-sm-12">
# <small for="exampleFormControlSelect1">Perusahaan</small>
# <select class="form-control js-example-basic-single" id="perusahaan" onchange="updateList()" style="width:100%;">
# <option selected="" value="all">Tampilkan Semua</option><option value="F9CEB2C5A6DF38BBA92B0E56567CAFEE">Perum Jasa Tirta I</option><option value="04A93A973D63734DBF8F6553C529B303">Perum Jasa Tirta II</option><option value="DB3E7868B03AB1BDF4D649A6D3184568">Perum Percetakan Uang Republik Indonesia</option><option value="24CAC792CDCE9582872729A4AA3075A3">Perum Perhutani</option><option value="8D09510EF6F5F596838775BC53CC7513">PT Bank Mandiri (Persero) Tbk</option><option value="11FA1B9C4022B5DCE7EFD44812BA16B5">PT Bank Rakyat Indonesia (Persero) Tbk</option><option value="59C6E76F209B61FEDF0FDDA56B7AC6C9">PT RNI (Persero) - ID FOOD - PT Berdikari</option><option value="05E5B8DDD66151E62B048780B1A0E092">PT Danareksa (Persero)</option><option value="B4AE940A86FA5AE52E610E5C7145F02B">PT Hutama Karya (Persero)</option><option value="B35CFFE6E161AA106861CA4A75251902">PT Industri Kereta Api (Persero)</option><option value="41C4E11F8FFAC6FE5B88F037675328B0">PT Jasa Marga (Persero) Tbk</option><option value="56C104B50AA6AFEABDD8CFB9ADD26C3E">PT Biofarma (Persero) - PT Kimia Farma Tbk</option><option value="0A65478A74A8E648A3AE36BDD8BFBA1B">PT RNI (Persero) - ID FOOD - PT Mitra Kerinci</option><option value="0A60F258D5690BD61B1F25CA91597F9C">PT Pelabuhan Indonesia (Persero)</option><option value="28B8D0483063147700815804E75D1BE6">PT Perkebunan Nusantara III (Persero) - PT Perkebunan Nusantara VII</option><option value="5E36778A4C9B23F7B71C63F5B5B725A4">PT Perusahaan Listrik Negara (Persero)</option><option value="F7C3270CC9065F3A9116238870EA5CBC">PT Pos Indonesia (Persero)</option><option value="16A595EF926E64DFBE05A37AC003EE35">PT Reasuransi Indonesia Utama (Persero)</option><option value="270C47481D3EB18F95D65E55DD0BC8D8">PT Semen Indonesia (Persero) Tbk</option><option value="9547A60A7F69926A0436C58026CC0866">PT Telkom Indonesia (Persero) Tbk</option><option value="A5329A812E93E665688FD681103E7DB5">PT Waskita Karya (Persero) Tbk</option><option value="10592FA043BEE9EB143E395482559B02">PT RNI (Persero) - ID FOOD - PT PG Candi Baru</option><option value="164667D993031EDE2ED4F1DF9DDCDCF3">Perum Perumnas</option><option value="A5EF4790118078192FB795EB4F953481">PT Adhi Karya (Persero) Tbk</option><option value="643DB1E81FE3DEF9572885FBB2B48AD4">PT ASDP Indonesia Ferry (Persero)</option><option value="DEEC2B3967BF81634C1EF621DADF68A9">PT Biro Klasifikasi Indonesia (Persero) - PT Surveyor Indonesia</option><option value="5BEB65CE914FA5543DC29553E65B73AA">PT Bahana Pembinaan Usaha Indonesia (Persero) - PT Jaminan Kredit Indonesia</option><option value="1CE05E66293429B75749477B3A07B718">PT Kereta Api Indonesia (Persero)</option><option value="36421E1021141FB8EAC11A4F9CB14FE8">PT Pertamina (Persero) - PT Kilang Pertamina Internasional - PT Kilang Pertamina Balikpapan</option><option value="0AF4E714B023B1BF86BC488DCABAA33F">PT Pembangunan Perumahan (Persero) Tbk</option><option value="4F1F910B4B6D912E9811087214281F95">PT Taspen (Persero)</option><option value="1F306D75F0DBD5133664A77A9F87A36D">PT Pupuk Indonesia (Persero)</option><option value="3E66497A02F208032AD4DEE4D9DA7DB6">Perum Damri</option><option value="8F62ABBB42E42EB5E52E15E50DED6371">PT Bank Negara Indonesia (Persero) Tbk</option><option value="3C0026DD18982CFAB3F3B7D5290550AC">PT Brantas Abipraya (Persero)</option><option value="41C757D37C24D2B65B1EDE1B90A37503">PT Virama Karya (Persero)</option><option value="D46C3BBF8E34D15F49408384308E06F1">PT Asabri (Persero)</option><option value="2D157B28790C8DDE9600C56CBAFBA633">PT Bio Farma (Persero) - PT Kimia Farma Tbk - PT Kimia Farma Diagnostika</option><option value="EB4DA69797AB748A76E8146F6FB4E61F">PT Biro Klasifikasi Indonesia (Persero)</option><option value="B28F6D401C92509C6D143290269565AD">PT Perkebunan Nusantara III (Persero) - PT Perkebunan Nusantara IV</option><option value="5B20BAD6ACA65DB13115B1A6267D45D2">PT Biofarma (Persero)</option><option value="C68D60E218B170C7C35CAD0D0422457D">PT BNI LIFE INSURANE - PT BANK NEGARA IND ...
# </div>
# <div class="form-group col-sm-12">
# <small for="exampleFormControlSelect1">Bidang Pekerjaan</small>
# <select class="form-control js-example-basic-single" id="job_function" onchange="updateList()" style="width:100%;">
# <option selected="" value="all">Tampilkan Semua</option>
# <option>Analyst Research</option>
# <option>Bisnis Niaga / Pemasaran</option>
# <option>Capital Market Investment Banking</option>
# <option>Developer Information Technology</option>
# <option>Digitalisasi and IT</option>
# <option>Engineering and Maintenance</option>
# <option>Keuangan</option>
# <option>Legal and Compliance</option>
# <option>Logistic / Supply Chain / Asset / GA</option>
# <option>Operasi / Produksi / Proyek</option>
# <option>Pengembangan Usaha / R and D</option>
# <option>Risiko Bisnis / Enterprise Risk</option>
# <option>Risk Management</option>
# <option>SDM / HC</option>
# <option>Sistem Management and Safety</option>
# <option>Strategic Planning</option>
# <option>Treasury</option>
# </select>
# </div>
# <div class="form-group col-sm-12">
# <small for="exampleFormControlSelect1">Jenjang</small>
# <select class="form-control js-example-basic-single" id="jenjang" onchange="updateList()" style="width:100%;">
# <option selected="" value="all">Tampilkan Semua</option>
# <option value="Diploma III">D3</option>
# <option value="Sarjana S1 / Diploma IV">Sarjana S1 / Diploma IV</option>
# <option value="S2-Pasca Sarjana">S2</option>
# </select>
# </div>
# <div class="form-group col-sm-12">
# <small for="exampleFormControlSelect1">Jurusan</small>
# <select class="form-control js-example-basic-single" id="jurusan" onchange="updateList()" style="width:100%;">
# <option selected="" value="all">Tampilkan Semua</option>
# <option>Akuntansi</option>
# <option>Desain Komunikasi Visual</option>
# <option>Ilmu Hukum</option>
# <option>Sistem Teknologi Informasi</option>
# <option>Manajemen Keuangan</option>
# <option>Ilmu Komunikasi</option>
# <option>Manajemen &amp; Administrasi</option>
# <option>Psikologi</option>
# <option>Statistik</option>
# <option>Teknik Elektro</option>
# <option>Teknik Industri</option>
# <option>Teknik Telekomunikasi</option>
# <option>Ilmu Komputer</option>
# <option>Teknik Informatika</option>
# <option>Aktuaria</option>
# <option>Manajemen</option>
# <option>Keuangan</option>
# <option>Sistem dan Teknologi Informasi</option>
# <option>Teknik Sipil</option>
# <option>Fisika</option>
# <option>Kedokteran</option>
# <option>Bisnis</option>
# <option>Matematika</option>
# <option>Teknik Mesin</option>
# <option>Sarjana Teknik</option>
# <option>Apoteker</option>
# <option>Ilmu Hukum Pidana dan Perdata</option>
# <option>Marketing</option>
# <option>Ekonomi &amp; Bisnis</option>
# <option>Sains</option>
# <option>Teknik Kimia</option>
# <option>Teknik Transportasi</option>
# <option>Analis Kesehatan</option>
# <option>Keperawatan</option>
# <option>Management SDM</option>
# <option>Kimia</option>
# <option>Farmasi</option>
# <option>Mikrobiologi</option>
# <option>Administrasi</option>
# <option>Public Relations</option>
# <option>Manajemen Akuntansi</option>
# <option>Teknik Tekstil</option>
# <option>Administrasi Bisnis</option>
# <option>Asuransi</option>
# <option>Manajemen bisnis</option>
# <option>Ekonomi</option>
# <option>Manajemen ekonomi dan bisnis</option>
# <option>Perpajakan/Pajak</option>
# <option>Sastra Indonesia</option>
# <option>Sastra Inggris</option>
# <option>Marketing Communication</option>
# <option>Desain Grafis</option>
# <option>Agroteknologi</option>
# <option>Agronomi</option>
# <option>Hama Penyakit Tanaman</option>
# <option>Budidaya Perkebunan</option>
# <option>Kehutanan</option>
# <option>Pertanian</option>
# <option>Bioteknologi</option>
# <option>Teknik Lingkungan</option>
# <option>Sosial Ekonomi</option>
# <option>Pendidikan Ilmu Komunikasi</option>
# <option>Ketenagakerjaan</option>
# <option>Sosial</option>
# <option>Administrasi Fiskal</option>
# <option>Manajemen Hutan</option>
# <option>Agribisnis</option>
# <option>Ekonomi Pembangunan</option>
# <option>Teknik Sipil bangunan Gedung</option>
# <option>Teknik geodesi/geodesi</option>
# <option>Geomatika</option>
# <option>Peternakan</option>
# <option>Teknologi Hasil Pertanian</option>
# <option>Bisnis Digital</option>
# <option>Teknologi Industri Pertanian</option>
# <option>Data Sicence &amp; Artificial Intelligence</option>
# <option>Teknik Robotika</option>
# <option>Seni Rupa dan Desain</option>
# <option>Biokimia</option>
# <option>Teknik Grafika</option>
# <option>Mikrobiologi Pertanian</option>
# <option>Proteksi Tanaman</option>
# <option>Manajemen Stratejik</option>
# <option>Manajemen Risiko</option>
# <option>Manajemen Aset</option>
# <option>Biologi</option>
# <option>Pemuliaan Tanaman</option>
# <option>Teknik Sipil (Teknik Sipil SDA)</option>
# <option>Rekayasa Pertanian</option>
# <option>Rekayasa Hayati</option>
# <option>Ilmu Tanah</option>
# <option>Ekonomi Manajemen</option>
# <option>Ekonomi Akuntansi</option>
# <option>Teknik Eletromedik</option>
# <option>Administrasi Negara</option>
# <option>Administrasi Perkantoran</option>
# <option>Manajemen Pemasaran</option>
# <option>Matematika Aktuaria</option>
# <option>Arsitektur</option>
# <option>Manajemen Logistik</option>
# <option>Kesehatan Lingkungan</option>
# <option>BUDIDAYA PERTANIAN</option>
# <option>TEKNIK PERTANIAN</option>
# <option>MEKANISASI PERTANIAN</option>
# <option>HAMA PENYAKIT PERTANIAN</option>
# <option>Teknik Fisika</option>
# <option>Mechanical Piping</option>
# <option>Instrument Electrical</option>
# <option>Nautika</option>
# <option>Teknik Perkapalan</option>
# <option>Teknik Sistem Perkapalan</option>
# <option>Sarjana Telekomunikasi</option>
# <option>Humas</option>
# <option>Teknologi Hasil Hutan</option>
# <option>Sistem Komputer</option>
# <option>Manajemen Asuransi</option>
# <option>Teknik Komputer</option>
# <option>Teknik Geoteknik</option>
# <option>sains komputer</option>
# <option>Manajemen Transportasi</option>
# <option>Teknik Pengolahan Limbah</option>
# <option>Manajemen Sistem Informasi</option>
# <option>Manajemen Informatika</option>
# <option>PDSK</option>
# <option>Sekretaris</option>
# <option>Ilmu Kesehatan</option>
# <option>Ilmu Pendidikan</option>
# <option>Semua Jurusan</option>
# </select>
# </div>
# <div class="form-group col-xs-12 col-sm-12 text-right">
# <button class="btn btn-outline-secondary clear_search btn-sm btn-rounded pl-4 pr-4" onclick="resetList();">Clear Filter</button>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-9 pr-0 pt-4 pt-md-0">
# <div class="nav-tabs-horizontal" style="z-index:5">
# <div class="row m-0">
# <div class="col-md-6 p-0 mb-2 pr-2 my-auto">
# <small class="total_avail" style="display:none">Total : <span id="total_vacancy">-</span> </small>
# <small class="total_not_avail" style="display:none">Total : <span id="total_vacancy_not_avail">-</span> </small>
# </div>
# <div class="col-md-6 p-0 mb-2 pr-2">
# </div>
# <div class="col-md-12 m-0 mb-2 pl-0 pr-2">
# <div class="tab-content">
# <div for="" style="padding: 10px 15px;margin-bottom: 10px;background: wheat;border-radius: 5px;display: flex;"><span class="material-icons">info</span><small class="my-auto">  Daftar posisi yang tertera dapat berubah sewaktu-waktu sesuai kebutuhan masing-masing BUMN. Harap melakukan pengecekan secara berkala.</small></div>
# </div>
# <div class="tab-pane active" id="job_available" role="tabcard" style="">
# <div class="result-wrapper">
# <ul class="list pl-0" id="list">
# <span class="text-center" style="display:block">Please Wait...</span>
# </ul>
# <div class="no-result text-center" style="display:none;">Data tidak ditemukan. Coba pencarian lain.</div>
# <ul class="pagination pull-right"></ul>
# <div class="row m-0">
# </div>
# </div>
# </div>
# <div class="tab-pane pl-0" id="job_not_available" role="tabcard" style="">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="tab-pane p-5" id="saved" role="tabcard">
# </div>
# </div>
# </div>
# <div class="background-left"></div>
# <div class="background-right"></div>
# </div>
# <script>
#   $(function(){
#     if (window.matchMedia("(max-width: 767px)").matches){
#       $('#collapseFilter').collapse();
#       $('#headingFilter').removeClass('active');
#       $('#btn-filter').html(`<button class="btn text-white float-right d-flex content-align-betweens" style="background-color: #0093AD !important;" data-toggle="collapse" data-target="#collapseFilter" aria-expanded="true" aria-controls="collapseFilter">
#         Show <span class="material-icons">arrow_drop_down</span>
#       </button>`);
#     }
#     $('#collapseFilter').on('show.bs.collapse', function () {
#       $('#headingFilter').addClass('active');
#       // filter open
#       $('#btn-filter').html(`<button class="btn text-white float-right d-flex content-align-betweens" style="background-color: #0093AD !important;" data-toggle="collapse" data-target="#collapseFilter" aria-expanded="true" aria-controls="collapseFilter">
#         Hide <span class="material-icons">arrow_drop_up</span>
#       </button>`);
#     });
#
#     $('#collapseFilter').on('hide.bs.collapse', function () {
#       $('#headingFilter').removeClass('active');
#       // filter closed
#       $('#btn-filter').html(`<button class="btn text-white float-right d-flex content-align-betweens" style="background-color: #0093AD !important;" data-toggle="collapse" data-target="#collapseFilter" aria-expanded="true" aria-controls="collapseFilter">
#         Show <span class="material-icons">arrow_drop_down</span>
#       </button>`);
#     });
#   });
# </script>
# </div>
#
# <!-- list_job_html -->
# <!-- job_not_found_html -->
# <style media="screen">
#   .form-control-error{
#     color: red;
#     font-size: 12px !important;
#   }
# </style>
# <div class="modal" id="TermsModal">
# <div class="modal-dialog">
# <div class="modal-content">
# <!-- Modal Header -->
# <div class="modal-header">
# <h4 class="modal-title">Ketentuan Dan Persyaratan</h4>
# <button class="close" data-dismiss="modal" type="button"><i class="material-icons">clear</i></button>
# </div>
# <!-- Modal body -->
# <div class="modal-body">
# <div class="row">
# <div class="col-md-12">
# <div class="form-group" style="text-align:justify;">
# <label class="" for="terms_accept_checkbox">
#                       Dengan melakukan registrasi pada portal rekrutmen ini, maka saya telah menyetujui dan mengizinkan penggunaan data diri dan dokumen persyaratan saya untuk proses rekrutmen yang dijalani.
#                     </label>
# <hr/>
# <label>Dengan ini saya menyatakan akan bertanggung jawab penuh atas kebenaran data dan keabsahan data pendukung serta dokumen terkait lainnya dalam mengikuti proses rekrutmen pada website ini. Apabila ditemukan adanya ketidaksesuaian/pemalsuan atas informasi yang saya sampaikan, maka saya bersedia menerima konsekuensi sesuai ketentuan yang berlaku.</label>
# </div>
# </div>
# </div>
# </div>
# <!-- Modal footer -->
# <div class="modal-footer" style="background:#0097b1 url('https://rekrutmenbersama.fhcibumn.id/assets/frontend/images/icon_chrome_summit.png') no-repeat fixed; background-size:200%">
# <button class="btn btn-light" data-dismiss="modal" type="">Tutup</button>
# </div>
# </div>
# </div>
# </div>
# <div class="modal" id="ConfirmInput">
# <div class="modal-dialog">
# <form id="form-register-confirm" method="POST" name="form-validation">
# <div class="modal-content">
# <div class="modal-header">
# <h4 class="modal-title">Konfirmasi Data</h4>
# <button class="close" data-dismiss="modal" type="button"><i class="material-icons">clear</i></button>
# <input name="csrf_fhci" style="display: none" type="hidden" value="840614c426d304dad46c6a463841f179"/>
# </div>
# <!-- Modal body -->
# <div class="modal-body">
# <div class="row">
# <div class="col-md-12">
# <div class="form-group">
# <label style="padding-bottom: 6px; font-size: 12pt;">Nama :</label>
# <h4 for="valid-name" id="valid-name" name="valid-name" style="font-size: 12pt; font-weight: bold; background-color: #CECECE; padding: 8px; border-radius: 4px;text-transform:uppercase"></h4>
# <!-- <i class="fa fa-check" style="background-color: #53D840; color:white; padding: 8px; border-radius: 8px;"></i> -->
# <!-- <input class="form-control" type="text" style="background-color: #53D840; color:white; padding: 7px; border-radius: 5px;" name="valid-name" id="valid-name" data-validation="[NOTEMPTY]"> -->
# </div>
# <div class="form-group">
# <label style="padding-bottom: 6px; font-size: 12pt;">KTP :</label>
# <h4 for="valid-ktp" id="valid-ktp" name="valid-ktp" style="font-size: 12pt; font-weight: bold; background-color: #CECECE; padding: 8px; border-radius: 4px;"></h4>
# <!-- <i class="fa fa-check" style="background-color: #53D840; color:white; padding: 8px; border-radius: 8px;"></i> -->
# ...
#                                     <b>`+$("#quota_vac_"+val.enc_vacancy_id).text()+`</b>
#                                 </div>
#                               </div>
#                               <div class="col-md-2 d-flex">
#                                 <div class="pt-2"><span class="circle"></span></div>
#                                 <div>
#                                     <small>Total Pendaftar :</small><br>
#                                     <b>`+$("#applied_"+val.enc_vacancy_id).text()+`</b>
#                                 </div>
#                               </div>
#                             </div>
#                           </div>
#                           <div class="col-md-12 p-3 my-auto text-right" style="border-top:solid 1px #cacaca">
#                             <button onclick="un_save_vacancy('`+val.enc_vacancy_id+`')" class="btn btn-outline-success btn-rounded btn-sm pl-4 pr-4">Remove</button>
#                             <a href="https://rekrutmenbersama.fhcibumn.id/main#job_vacancy/detail/`+val.enc_vacancy_id+`" class="btn btn-success btn-rounded btn-sm pl-4 pr-4">Detail</a>
#                           </div>
#             </div>`
#           )
#         });
#
#         if ($('.card-list-vacancy-saved').length == 0) {
#           $("#saved").append(`<p class="text-center"><span class="material-icons mb-2" style="background: white;padding: 1rem;border-radius: 10px;">block</span><p class="text-center">No Vacancies saved</p></p>`)
#         }
#         NProgress.done();
#       })
#     }
#
#
#     function apply_job(jr,jf){
#       // $('#apply-job').click(function(e){
#           // e.preventDefault();
#           var vacancy_id = 1;
#           NProgress.start();
#           $.ajax({
#
#               url: 'home/is_login',
#               type: 'POST',
#               dataType: 'json',
#               data : {vacancy_id : vacancy_id},
#
#           })
#           .done(function(data) {
#               if(data.status){
#                   //alert(data.url);
#                    document.location.href=data.url+'/'+jr+'/'+jf+'/'+$("#regional").val();
#               }
#               else{
#                   if (data.msg == "bukan pelamar") {
#                       swal({
#                               title: "Informasi",
#                               text: "Untuk dapat melamar pekerjaan, silahkan logout terlebih dahulu.",
#                               type: "error",
#                               confirmButtonClass: "btn-danger"
#                           });
#                   }
#                   else{
#                       $("#modal_direct_login").modal('show');
#                       // $('#vacancy_id').val('');
#                       // console.log("l");
#
#                   }
#
#               }
#               NProgress.done();
#           })
#
#       // });
#     }
#
#     function load_total_applied(){
#           NProgress.start();
#           $("#job_not_available").empty();
#           $.ajax({
#               url: 'job/load_total_applied',
#               type: 'POST',
#               dataType: 'json',
#               data : {},
#           })
#           .done(function(data) {
#             $.each(data,function(i,val){
#               gap = val.total_job_available - val.total_applied;
#
#               if (gap <= 0) {
#                 total_job_not_available ++;
#                 $("#applied_"+val.enc).text(val.total_job_available);
#                 $("#section_btn_detail_"+val.enc).empty().append(`<span>Quota Penuh</span>`);
#                 $("#section_btn_save_"+val.enc).empty();
#                 $("#"+val.enc).addClass('job_not_available');
#
#                 //saved
#                 $("#saved_applied_"+val.enc).text(val.total_job_available);
#                 $("#section_btn_detail_saved_"+val.enc).empty().append(`<span>Quota Penuh</span>`);
#
#                 $("#job_not_available").append(`<div class="row card-list-vacancy list--list-item mb-2 m-0 job_not_available">`+$("#"+val.enc).html()+`</div>`);
#                 $("#"+val.enc).remove();
#
#               }
#               else {
#                 if ('job' == 'job') {
#                   href = 'https://rekrutmenbersama.fhcibumn.id/job/detail/'+val.enc;
#                 }
#                 else{
#                   href = 'https://rekrutmenbersama.fhcibumn.id/main#job_vacancy/detail/'+val.enc;
#                 }
#                 $("#applied_"+val.enc).text(val.total_applied);
#                 $("#section_btn_detail_"+val.enc).empty().append(`<a href="`+href+`" class="btn btn-success btn-rounded btn-sm pl-4 pr-4">Detail</a>`);
#
#                 //saved
#                 $("#saved_applied_"+val.enc).text(val.total_applied);
#                 $("#section_btn_detail_saved_"+val.enc).empty().append(`<a href="`+href+`" class="btn btn-success btn-rounded btn-sm pl-4 pr-4">Detail</a>`);
#               }
#
#
#             });
#             userList = new List('users', options);
#             $('#list').show();
#
#             total_job_available = total_job_available - total_job_not_available;
#
#             // $("#total_vacancy").text(total_job_available+" Posisi Tersedia");
#             // $("#total_vacancy_not_avail").text(total_job_not_available+" Quota Penuh");
#
#             NProgress.done();
#           })
#     }
#
#     function show_total(type){
#       if (type == 'avail') {
#         // $(".total_avail").show();
#         // $(".total_not_avail").hide();
#       }
#       else {
#         // $(".total_avail").hide();
#         // $(".total_not_avail").show();
#       }
#     }
#
#     function loadPagination(){
#       // $("#saved").hide();
#             $('#list').html('<div class="col-xs-12 mx-auto text-center"><div class="d-flex justify-content-center"><i class="fa fa-spin fa-3x fa-circle-o-notch"></i></div></div>');
#
#             $.ajax({
#                 url: base_url+'job/loadRecord/',
#                 type: 'post',
#                 data: {
#                   company: $("#perusahaan").val(),
#                   vacancy_name: $("#name_vacancy").val(),
#                 },
#                 dataType: 'json',
#                 beforeSend: function(){
#
#                 },
#                 success: function(data){
#                     list_card = '';
#                     response = data.data;
#                     saved = data.saved;
#
#                     $('#pagination').html(response.pagination);
#
#                     if (response.result.length < 1 ) {
#                       $('#list').html('<div class="col-xs-12 mx-auto text-center no-job-available" style="border: 1px solid red;background: antiquewhite;"><i class="material-icons" style="background: white;font-size: 50px;padding: 30px;border-radius: 50%;/*! box-shadow: 0 6px 15px rgba(36, 37, 38, 0.25); */color: red;">extension</i><h5 style="margin-top: 20px;">No job available</h5></div>');
#                     }
#                     else{
#                       $("#total_open").text(response.result.length);
#
#                       // jika saved kosong
#                       if (saved.length == 0) {
#                         $("#saved").append(`<p class="text-center">
#                           <span class="material-icons mb-2" style="background: white;padding: 1rem;border-radius: 10px;">block</span>
#                           <p class="text-center">No Vacancies saved</p>
#                         </p>`)
#                       }
#
#                       $.each(response.result,function(i,val){
#                           if ('job' == 'job') {
#                             href = val.vacancy_base_url+'job/detail/'+val.vacancy_id;
#                             $("#saved").hide();
#                           }
#                           else{
#                             href = val.vacancy_base_url+'main#job_vacancy/detail/'+val.vacancy_id;
#                           }
#
#                           // saved
#                           is_saved = 0;
#                           if (saved.length > 0) {
#                             $.each(saved,function(x,y){
#                               if (y.enc_vacancy_id == val.vacancy_id) {
#                                 $("#saved").append(`<div id="`+val.vacancy_id+`" class="row card-list-vacancy-saved" >
#                                   <div class="col-md-12 p-3 center-list-job" style="">
#                                     <h5 style="margin-bottom: 5px;color:#219BA8">`+val.vacancy_name+`</h5>
#                                     <p class="color-grey">`+val.tenant_name+`</p>
#                                     <div class="row">
#
#                                       <div class="col-md-6 d-flex">
#                                         <div class="mt-2"><span class="circle"></span></div>
#                                         <div>
#                                           <small>Bidang : </small><br>
#                                           <strong>`+val.stream_name+`</strong>
#                                         </div>
#                                       </div>
#                                       <div class="col-md-6 d-flex">
#                                         <div class="mt-2"><span class="circle"></span></div>
#                                         <div>
#                                           <small>Jenjang :</small><br>
#                                           <b>`+val.jenjang+`</b>
#                                         </div>
#                                       </div>
#                                     </div>
#                                   </div>
#                                   <div class="col-md-12 p-3 my-auto text-right" style="border-top:solid 1px #cacaca">
#                                     <button onclick="un_save_vacancy('`+val.vacancy_id+`')" class="btn btn-outline-success btn-rounded btn-sm pl-4 pr-4">Remove</button>
#                                     <span id="section_btn_detail_saved_`+val.vacancy_id+`"></span>
#                                   </div>
#                                 </div>`);
#                                 is_saved = 1;
#                                 return false;
#                               }
#                             })
#                           }
#
#                           if ('job' == 'job') {
#                             btn_save = '';
#                           }
#                           else{
#                             if (is_saved == 0) {
#                               btn_save = `<button onclick="save_vacancy('`+val.vacancy_id+`')" class="btn btn-outline-success btn-rounded btn-sm pl-4 pr-4">Save</button>`;
#                             }
#                             else if (is_saved == 1) {
#                               btn_save = `<span class="pl-3 pr-3 pt-2 pb-2" style="background: whitesmoke;border-radius: 20px;">Saved</span>`;
#                             }
#                           }
#
#                           if (val.jurusan_filter_type == 'in') {
#                             var jurusan_name = `<div id="group_jurusan_`+val.vacancy_id+`"><small id="name_jurusan_`+val.vacancy_id+`" class="jurusan">`+val.jurusan_name.replace('[','').replace(']','').replace(/[""]/g,'').replace(',',',&nbsp;')+`</small></div>`;
#                           }
#                           else if (val.jurusan_filter_type == 'not_in') {
#                             var jurusan_name = `<div id="group_jurusan_`+val.vacancy_id+`"><small id="name_jurusan_`+val.vacancy_id+`" class="jurusan">Semua Jurusan</small><br><small style="text-decoration:underline">KECUALI : `+val.jurusan_name.replace('[','').replace(']','').replace(/[""]/g,'').replace(',',',&nbsp;')+`</small></div>`;
#                           }
#                           else if (val.jurusan_filter_type == 'all') {
#                             var jurusan_name = `<div id="group_jurusan_`+val.vacancy_id+`"><small id="name_jurusan_`+val.vacancy_id+`" class="jurusan">Semua Jurusan</small></div>`;
#                           }
#
#                           list_card += `<div id="`+val.vacancy_id+`" data-company="`+val.tenant_id+`"  class="row card-list-vacancy m-0 list--list-item mb-2" >
#                             <div class="col-md-12 center-list-job p-3" style="">
#                               <strong id="name_vac_`+val.vacancy_id+`" class="name" style="margin-bottom: 5px;color:#219BA8">`+val.vacancy_name+`</strong><br>
#                               <small class="" id="name_tenant_`+val.vacancy_id+`">`+val.tenant_name+`</small>
#                               <div class="row mt-2">
#
#                                 <div class="col-md-6 d-flex">
#                                   <div class="mt-2"><span class="circle"></span></div>
#                                   <div>
#                                     <small class="color-grey">Bidang : </small><br>
#                                     <small id="name_stream_`+val.vacancy_id+`" class="job_function">`+val.stream_name+`</small>
#                                   </div>
#                                 </div>
#                                 <div class="col-md-6 d-flex">
#                                   <div class="mt-2"><span class="circle"></span></div>
#                                   <div>
#                                     <small class="color-grey">Jenjang :</small><br>
#                                     <small id="name_jenjang_`+val.vacancy_id+`" class="jenjang">`+val.jenjang+`</small>
#                                   </div>
#                                 </div>
#                                 <div class="col-md-12 mt-3 d-flex">
#                                   <div class="mt-2"><span class="circle"></span></div>
#                                   <div>
#                                     <small class="color-grey">Jurusan :</small><br>
#                                     `+jurusan_name+`
#                                   </div>
#                                 </div>
#                               </div>
#                             </div>
#                             <div class="col-md-12 my-auto text-right p-3" style="border-top:solid 1px #cacaca">
#                               <span id="section_btn_save_`+val.vacancy_id+`">`+btn_save+`</span>
#                               <span id="section_btn_detail_`+val.vacancy_id+`"><a href="`+href+`" class="btn btn-success btn-rounded btn-sm pl-4 pr-4">Detail</a></span>
#                             </div>
#                           </div>`;
#
#
#                       });
#                     }
#
#
#                     $('#list').empty().hide();
#                     $("#list").append(list_card);
#                     // load_total_applied();
#                     // total_job_available = response.result.length;
#                     userList = new List('users', options);
#                     // userList.show(2, 10); // Display item 4,5,6
#                     $('#list').show();
#                     $('#perusahaan').prop('disabled', false);
#                     $('#job_function').prop('disabled', false);
#                     $('#jenjang').prop('disabled', false);
#                     $('#jurusan').prop('disabled', false);
#
#                     $(".search").prop('disabled', false);
#                 }
#             });
#     }
#
# </script>
# <script type="text/javascript">
# $(document).ready(function(){
#
#   $(".animsition").animsition({
#     inClass: 'fade-in',
#     outClass: 'fade-out',
#     inDuration: 1500,
#     outDuration: 8000,
#     linkElement: '.animsition-link',
#     // e.g. linkElement: 'a:not([target="_blank"]):not([href^="#"])'
#     loading: true,
#     loadingParentElement: 'body', //animsition wrapper element
#     loadingClass: 'loading_tg',
#     loadingInner: '', // e.g '<img src="loading.svg" />'
#     timeout: true,
#     timeoutCountdown: 2000,
#     onLoadEvent: false,
#     browser: [ 'animation-duration', '-webkit-animation-duration'],
#     // "browser" option allows you to disable the "animsition" in case the css property in the array is not supported by your browser.
#     // The default setting is to disable the "animsition" in a browser that does not support "animation-duration".
#     overlay : false,
#     overlayClass : 'animsition-overlay-slide',
#     overlayParentElement : 'body',
#     transition: function(url){ window.location.href = url; }
#   });
#
#
# });
# </script>
# </link>

# %%
jobs = page.find_all("div", class_="result-wrapper")

# %%
a = jobs[0].find("ul")

# %%
a
# Out:
# <ul class="list pl-0" id="list">
# <span class="text-center" style="display:block">Please Wait...</span>
# </ul>

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 job = ul[0].find("div")
#
# File ~/venv/ML-1/lib/python3.10/site-packages/bs4/element.py:1519, in Tag.__getitem__(self, key)
#    1516 def __getitem__(self, key):
#    1517     """tag[key] returns the value of the 'key' attribute for the Tag,
#    1518     and throws an exception if it's not there."""
# -> 1519     return self.attrs[key]
#
# KeyError: 0

# %%
# Out:
# <div class="result-wrapper">
# <ul class="list pl-0" id="list">
# <span class="text-center" style="display:block">Please Wait...</span>
# </ul>
# <div class="no-result text-center" style="display:none;">Data tidak ditemukan. Coba pencarian lain.</div>
# <ul class="pagination pull-right"></ul>
# <div class="row m-0">
# </div>
# </div>
