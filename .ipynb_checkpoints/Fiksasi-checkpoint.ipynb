# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import pandas as pd

url = "https://rekrutmenbersama.fhcibumn.id/job"


driver = webdriver.Chrome(executable_path='/home/athoillah/Downloads/chromedriver_linux64/chromedriver')
driver.get(url)

driver.implicitly_wait(30)

Links = [] 

jobs_block = driver.find_element(By.XPATH, """//*[@id="list"]""")


# Page 1
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 2
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[2]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)


# To Page 3
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[3]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 4
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[4]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 5
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 6
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 7
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 8
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 9
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 10
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 11
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 12
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 13
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 14
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 15
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 16
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 17
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 18
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 19
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 20
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 21
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 22
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 23
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 24
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 25
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 26
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 27
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 28
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 29
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 30
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 31
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)

# To Page 32
driver.find_element(By.XPATH, f"""//*[@id="job_available"]/div/ul[2]/li[5]/a""").click()
time.sleep(3)
link_list = jobs_block.find_elements(By.TAG_NAME,"a")
for link in link_list:
    link0 = link.get_attribute('href')
    Links.append(link0)


print('Found ' + str(len(Links)) + ' for job offers')
# Out:
# /tmp/ipykernel_1118541/648405490.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='/home/athoillah/Downloads/chromedriver_linux64/chromedriver')
# Found 312 for job offers

# %%
Links
# Out:
# ['https://rekrutmenbersama.fhcibumn.id/job/detail/F32617A8126F7846DFF9CF0DF2C4324F',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/0AD2FA87F75F7D5A34421A49F0C7B847',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/07ECBDD649EF2DFE6576E314AEB7C5FC',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/4B5B56707F555A7DC7FDEADC792C846C',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/F14A4F2271060EA616C85981A5AF3165',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/84036CF360EF566505B07B0596629333',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/0BD5C10A4E9DFDC989332399A181A7DE',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/10B3CA18588D63FE20C1F4BD8A3569C4',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/413BAB3EEA87749B564196C0CAD40E0A',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/706A78F4E3DFCC1B23D3C8FEE5A7564A',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/A79FFDE728DB598DDD94A969F1C1C8AB',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/FE83B344FF546754E34311B483479F15',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/681E0B3579BFE857A688465380A3F945',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/2CB019E1A7900BC9955849CB52126D17',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/F5312791AFF366F7EF2BDCEBA0B91018',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/72442BCF11964E615BD86A38CD557F63',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/AF7925F1616500A6E33D532707154706',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/F674B81A7AA884B2A85F5EC8850E36F0',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/3F7B11D79F83E0B14C4D8845FC9DE99D',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/33FA6718938571791D2AC754B417AFFE',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/B856B014E099F8B1466AD0EBD09D4115',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/A2717DB8C9E521C5F7D5DF98368BCBCE',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/4C4FB46EDB73E9554A01A6913DEA8DDC',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/03FF90EFF2408C887CAD55C1CF387CE1',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/6AE1E689AF1AB7AE14D7102009FA3612',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/F6B1CEB1DF9B2EF244795EC96A39C012',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/97AB60B21C5712043ADE5853ABBBDD0F',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/85373BBC80D5CBACDFA060576E53D894',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/69146EB19CFCB545CA7777231D51BBCE',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/595A05D656FFADA3B3F7C8811C088B72',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/A2B8995A2394A52597A7A3B72D9CE9A0',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/BCFCA38634BC270077AEC62E8D34E891',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/A1C6CFD648349B4D73E3D398D92168D2',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/C0BB53107CC35E3E2433E90B8D3CDDF2',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/4913DC5AEBE1D261C5238E0C8AE30E14',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/DD1C25E712B52941E934C7E60B1584F1',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/C6D584D067B5F60D99F5FC7B793C2E98',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/7406103E18C3F16FB93D4CAE24739619',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/33454E930A282681059F0216BBC653AF',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/D21A88666E8510A0B1E90EB5452AF499',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/

#  'https://rekrutmenbersama.fhcibumn.id/job/detail/0641293AEC6269049A1F74DFAA578FB7',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/B7690587157464399AB8B02623B78C81',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/8FBF351BF26DAE24488BEF9BEF5912F9',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/8F65B2EEDCDBA7363DB77D649A967C65',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/2765FEBE2855C78B836E0248A16F2796',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/AF187E06E9CF90997D64381CCB00BB58',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/725A362794B53AAFC5ED1F39A5CCBD7E',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/08524D89F979015D1AEA34057A965673',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/4EB5E3CAE908480FA456F339F340767F',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/489F1B014F20C77073B9469506080E38',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/EB089A5ABA5457CDB75D915FAF6031BA',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/9581A1747F3F1A958D9DB3265008E43F',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/2463EED69E2D23E3952D46A4460102AE',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/6CE11A6D2F208A122B45402DB6EF0F53',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/B66A42DC156EDE24860EB958070B6C2E',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/D7E3F4F7242F076598D9E91AF13DB895',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/7F1B615F8688875D3AE66CD5D549E475',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/A96BBEC970BB440BC6B441B96C4F758B',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/24A27D30E6C1D6B0E0373C74EB9480DA',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/CCABBE2AFCFB2B3F2CEF44D530C433D5',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/B2CD7FCB53904F0EC958C38E437E32BA',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/33CF58BED7B591FF68C4D83EE68C18CA',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/C4CCA87506885BDCC1397A9F95A943CA',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/ECF0DB87681793A238D3A6B1E55641E0',
#  'https://rekrutmenbersama.fhcibumn.id/job/detail/6F33806BDC88799839894794DA3B3258']

# %%
Posisi = []
Perusahaan = []
Bidang = []
Jenjang = []
Jurusan = []
Requirement = []

print('Visiting the links and collecting information just started....')

for i in range(len(Links)):
    try:
        driver.get(Links[i])
        i=i+1
        time.sleep(2)
    except:
        pass
    
    try:
        po_path = '/html/body/div[1]/div[3]/div/div/div/div/div[2]/h4/b'
        po0 = driver.find_element(By.XPATH,po_path).get_attribute('innerText')
        Posisi.append(po0)
    except:
        po1 = 'Empty Cause Error Network'
        Posisi.append(po1)
        
    try:
        pe_path = '/html/body/div[1]/div[3]/div/div/div/div/div[2]/p'
        pe0 = driver.find_element(By.XPATH,pe_path).get_attribute('innerText')
        Perusahaan.append(pe0)
    except:
        pe1 = 'Empty Cause Error Network'
        Perusahaan.append(pe1)
        
    try:
        bi_path = '/html/body/div[1]/div[3]/div/div/div/div/div[2]/div/div/div[1]/div[2]/p'
        bi0 = driver.find_element(By.XPATH,bi_path).get_attribute('innerText')
        Bidang.append(bi0)
    except:
        bi1 = 'Empty Cause Error Network'
        Bidang.append(bi1)
        
    try:
        je_path = '/html/body/div[1]/div[3]/div/div/div/div/div[2]/div/div/div[2]/div[2]/p'
        je0 = driver.find_element(By.XPATH,je_path).get_attribute('innerText')
        Jenjang.append(je0)
    except:
        je1 = 'Empty Cause Error Network'
        Jenjang.append(je1)
        
    try:
        driver.get(Links[i])
        i=i+1
        time.sleep(2)
    except:
        pass
    #_________________________________________________________________________Jurusan
    try:
        ju_path = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[1]/div/ol'
        ju0 = driver.find_element(By.XPATH,ju_path).get_attribute('innerText')
        Jurusan.append(ju0)
    except:
        pass
    
    try:
        ju_path1 = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[1]/div/p'
        ju1 = driver.find_element(By.XPATH,ju_path1).get_attribute('innerText')
        Jurusan.append(ju1)
    except:
        ju2 = 'Empty Cause Error Network'
        Jurusan.append(ju2)
    
    #_________________________________________________________________________Requirement
    try:
        re_path = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div/ol'
        re0 = driver.find_element(By.XPATH,re_path).get_attribute('innerText')
        Requirement.append(re0)
    except:
        pass
    
    try:
        re_path1 = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div/ul'
        re1 = driver.find_element(By.XPATH,re_path1).get_attribute('innerText')
        Requirement.append(re1)
    except:
        pass
    
    try:
        re_path2 = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div'
        re2 = driver.find_element(By.XPATH,re_path2).get_attribute('innerText')
        Requirement.append(re2)
    except:
        re3 = 'Empty Cause Error Network'
        Requirement.append(re3)
        
    print("Current at: ", i, ", Percentage at: ", (i+1)/len(Links)*100, "%",end="\r")
# Out:
# Visiting the links and collecting information just started....
# Current at:  312 , Percentage at:  100.32051282051282 %

# %%
data = pd.DataFrame({
    'Posisi': Posisi,
    'Perusahaan': Perusahaan,
    'Bidang': Bidang,
    'Jenjang': Jenjang,
    'Jurusan': Jurusan,
    'Requirement': Requirement,
    'Link': Links
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 data = pd.DataFrame({
#       2     'Posisi': Posisi,
#       3     'Perusahaan': Perusahaan,
#       4     'Bidang': Bidang,
#       5     'Jenjang': Jenjang,
#       6     'Jurusan': Jurusan,
#       7     'Requirement': Requirement,
#       8     'Link': Links
#       9 })
#
# File ~/venv/ML-1/lib/python3.10/site-packages/pandas/core/frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File ~/venv/ML-1/lib/python3.10/site-packages/pandas/core/internals/construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
#     496         if not hasattr(x, "dtype") or not isinstance(x.dtype, ExtensionDtype)
#     497         else x.copy()
#     498         for x in arrays
#     499     ]
#     500     # TODO: can we get rid of the dt64tz special case above?
# --> 502 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/venv/ML-1/lib/python3.10/site-packages/pandas/core/internals/construction.py:120, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     117 if verify_integrity:
#     118     # figure out the index, if necessary
#     119     if index is None:
# --> 120         index = _extract_index(arrays)
#     121     else:
#     122         index = ensure_index(index)
#
# File ~/venv/ML-1/lib/python3.10/site-packages/pandas/core/internals/construction.py:674, in _extract_index(data)
#     672 lengths = list(set(raw_lengths))
#     673 if len(lengths) > 1:
# --> 674     raise ValueError("All arrays must be of the same length")
#     676 if have_dicts:
#     677     raise ValueError(
#     678         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     679     )
#
# ValueError: All arrays must be of the same length

# %%
data.to_csv("FHCI_Desember2022.csv", index=False)

# %%
print(len(Posisi))
# Out:
# 312

# %%
print(len(Perusahaan))
# Out:
# 312

# %%
print(len(Bidang))
# Out:
# 312

# %%
print(len(Jenjang))
# Out:
# 312

# %%
print(len(Jurusan))
# Out:
# 574

# %%
print(len(Requirement))
# Out:
# 558

# %%
Requirement3 = []
for i in range(len(Links)):
    try:
        driver.get(Links[i])
        i=i+1
        time.sleep(2)
    except:
        pass
    
    try:
        re_path = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div/ol'
        re0 = driver.find_element(By.XPATH,re_path).get_attribute('innerText')
        Requirement3.append(re0)
    except:
        try:
            re_path1 = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div/ul'
            re1 = driver.find_element(By.XPATH,re_path1).get_attribute('innerText')
            Requirement3.append(re1)
        except:
            try:
                re_path2 = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div'
                re2 = driver.find_element(By.XPATH,re_path2).get_attribute('innerText')
                Requirement3.append(re2)
            except:
                re3 = 'Empty Cause Error Network'
                Requirement3.append(re3)
                
    print("Current at: ", i, ", Percentage at: ", (i+1)/len(Links)*100, "%",end="\r")

# for i in range(len(Links)):
#     try:
#         re_path = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div/ol'
#         re_path1 = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div/ul'
#         re_path2 = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div'

#         if re0 == driver.find_element(By.XPATH,re_path).get_attribute('innerText'):
#             Requirement1.append(re0)
#         elif re1 == driver.find_element(By.XPATH,re_path1).get_attribute('innerText'):
#             Requirement1.append(re1)
#         elif re2 == driver.find_element(By.XPATH,re_path2).get_attribute('innerText'):
#             Requirement1.append(re2)
#     except:
#         re3 = 'Empty Cause Error Network'
#         Requirement1.append(re3)
        
#     print("Current at: ", i, ", Percentage at: ", (i+1)/len(Links)*100, "%",end="\r")
# Out:
# Current at:  311 , Percentage at:  100.0 %8717948718 %%

# %%
Requirement3 = []
for i in range(len(Links)):
    driver.get(Links[i])
    i=i+1
    time.sleep(2)
    re_path = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div/ol'
    re0 = driver.find_element(By.XPATH,re_path).get_attribute('innerText')
    Requirement3.append(re0)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/venv/ML-1/lib/python3.10/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/venv/ML-1/lib/python3.10/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/venv/ML-1/lib/python3.10/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/venv/ML-1/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/venv/ML-1/lib/python3.10/site-packages/urllib3/connectionpool.py:398, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397     else:
# --> 398         conn.request(method, url, **httplib_request_kw)
#     400 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     401 # legitimately able to close the connection after sending a valid response.
#     402 # With this behaviour, the received response is still readable.
#
# File ~/venv/ML-1/lib/python3.10/site-packages/urllib3/connection.py:239, in HTTPConnection.request(self, method, url, body, headers)
#     238     headers["User-Agent"] = _get_default_user_agent()
# --> 239 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File /usr/lib/python3.10/http/client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File /usr/lib/python3.10/http/client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.10/http/client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.10/http/client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#
# File /usr/lib/python3.10/http/client.py:975, in HTTPConnection.send(self, data)
#     974 if self.auto_open:
# --> 975     self.connect()
#     976 else:
#
# File ~/venv/ML-1/lib/python3.10/site-packages/urllib3/connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File ~/venv/ML-1/lib/python3.10/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7fc43587f550>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# Input In [57], in <cell line: 2>()
#       1 Requirement3 = []
#       2 for i in range(len(Links)):
# ----> 3     driver.get(Links[i])
#       4     i=i+1
#       5     time.sleep(2)
#
# File ~/venv/ML-1/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:440, in WebDriver.get(self, url)
#     436 def get(self, url: str) -> None:
#     437     """
#     438     Loads a web page in the current browser session.
#     439     """
# --> 440     self.execute(Command.GET, {'url': url})
#
# File ~/venv/ML-1/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:426, in WebDriver.execute(self, driver_command, params)
#     423         params['sessionId'] = self.session_id
#     425 params = self._wrap_value(params)
# --> 426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
#     428     self.error_handler.check_response(response)
#
# File ~/venv/ML-1/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:344, in RemoteConnection.execute(self, command, params)
#     342 data = utils.dump_json(params)
#     343 url = f"{self._url}{path}"
# --> 344 return self._request(command_info[0], url, body=data)
#
# File ~/venv/ML-1/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:366, in RemoteConnection._request(self, method, url, body)
#     363     body = None
#     365 if self.keep_alive:
# --> 366     response = self._conn.request(method, url, body=body, headers=headers)
#     367     statuscode = response.status
#     368 else:
#
# File ~/venv/ML-1/lib/python3.10/site-packages/urllib3/request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~/venv/ML-1/lib/python3.10/site-packages/urllib3/request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File ~/venv/ML-1/lib/python3.10/site-packages/urllib3/poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~/venv/ML-1/lib/python3.10/site-packages/urllib3/connectionpool.py:815, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     810 if not conn:
#     811     # Try again
#     812     log.warning(
#     813         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     814     )
# --> 815     return self.urlopen(
#     816         method,
#     817         url,
#     818         body,
#     819         headers,
#     820         retries,
#     821         redirect,
#     822         assert_same_host,
#     823         timeout=timeout,
#     824         pool_timeout=pool_timeout,
#     825         release_conn=release_conn,
#     826         chunked=chunked,
#     827         body_pos=body_pos,
#     828         **response_kw
#     829     )
#     831 # Handle redirect?
#     832 redirect_location = redirect and response.get_redirect_location()
#
# File ~/venv/ML-1/lib/python3.10/site-packages/urllib3/connectionpool.py:815, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     810 if not conn:
#     811     # Try again
#     812     log.warning(
#     813         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     814     )
# --> 815     return self.urlopen(
#     816         method,
#     817         url,
#     818         body,
#     819         headers,
#     820         retries,
#     821         redirect,
#     822         assert_same_host,
#     823         timeout=timeout,
#     824         pool_timeout=pool_timeout,
#     825         release_conn=release_conn,
#     826         chunked=chunked,
#     827         body_pos=body_pos,
#     828         **response_kw
#     829     )
#     831 # Handle redirect?
#     832 redirect_location = redirect and response.get_redirect_location()
#
# File ~/venv/ML-1/lib/python3.10/site-packages/urllib3/connectionpool.py:815, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     810 if not conn:
#     811     # Try again
#     812     log.warning(
#     813         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     814     )
# --> 815     return self.urlopen(
#     816         method,
#     817         url,
#     818         body,
#     819         headers,
#     820         retries,
#     821         redirect,
#     822         assert_same_host,
#     823         timeout=timeout,
#     824         pool_timeout=pool_timeout,
#     825         release_conn=release_conn,
#     826         chunked=chunked,
#     827         body_pos=body_pos,
#     828         **response_kw
#     829     )
#     831 # Handle redirect?
#     832 redirect_location = redirect and response.get_redirect_location()
#
# File ~/venv/ML-1/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     784 elif isinstance(e, (SocketError, HTTPException)):
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#     792 # Keep track of the error for the retry warning.
#
# File ~/venv/ML-1/lib/python3.10/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     581 new_retry = self.new(
#     582     total=total,
#     583     connect=connect,
#    (...)
#     588     history=history,
#     589 )
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#     596 return new_retry
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=42773): Max retries exceeded with url: /session/5195b855cc9f5d19bc9b93b0ae61a15f/url (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fc43587f550>: Failed to establish a new connection: [Errno 111] Connection refused'))

# %%
# for i in range(len(Links)):
#     try:
#         driver.get(Links[i])
#         i=i+1
#         time.sleep(2)
#     except:
#         pass
#     #_________________________________________________________________________Jurusan
#     try:
#         ju_path = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[1]/div/ol'
#         ju0 = driver.find_element(By.XPATH,ju_path).get_attribute('innerText')
#         Jurusan.append(ju0)
#     except:
#         pass
    
#     try:
#         ju_path1 = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[1]/div/p'
#         ju1 = driver.find_element(By.XPATH,ju_path1).get_attribute('innerText')
#         Jurusan.append(ju1)
#     except:
#         ju2 = 'Empty Cause Error Network'
#         Jurusan.append(ju2)
    
#     #_________________________________________________________________________Requirement
#     try:
#         re_path = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div/ol'
#         re0 = driver.find_element(By.XPATH,re_path).get_attribute('innerText')
#         Requirement.append(re0)
#     except:
#         pass
    
#     try:
#         re_path1 = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div/ul'
#         re1 = driver.find_element(By.XPATH,re_path1).get_attribute('innerText')
#         Requirement.append(re1)
#     except:
#         pass
    
#     try:
#         re_path2 = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div'
#         re2 = driver.find_element(By.XPATH,re_path2).get_attribute('innerText')
#         Requirement.append(re2)
#     except:
#         re3 = 'Empty Cause Error Network'
#         Requirement.append(re3)
        
#     print("Current at: ", i, ", Percentage at: ", (i+1)/len(Links)*100, "%",end="\r")

# %%
# po_path = '/html/body/div[1]/div[3]/div/div/div/div/div[2]/h4/b'
# pe_path = '/html/body/div[1]/div[3]/div/div/div/div/div[2]/p'
# bi_path = '/html/body/div[1]/div[3]/div/div/div/div/div[2]/div/div/div[1]/div[2]/p'
# je_path = '/html/body/div[1]/div[3]/div/div/div/div/div[2]/div/div/div[2]/div[2]/p'
# ju_path = '/html/body/div[1]/div[4]/div/div/div[1]/div/div[1]/div/ol' else '/html/body/div[1]/div[4]/div/div/div[1]/div/div[1]/div/p' {semua jurusan/tanpa angka}
# re_path = ''

# /html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div/ol ==> angka
# /html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div/ol

# /html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div/ul ==> point

# /html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div ==> nothing
# /html/body/div[1]/div[4]/div/div/div[1]/div/div[2]/div
