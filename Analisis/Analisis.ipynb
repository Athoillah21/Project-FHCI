# %%
import pandas as pd

df = pd.read_csv(f'/home/athoillah/Documents/FHCI/FHCI_Desember2022.csv')

# %%
df
# Out:
#                            Posisi                             Perusahaan  \
# 0                  Staf Teknologi       PT Industri Kereta Api (Persero)
# 1         Staf Pengelolaan Proyek       PT Industri Kereta Api (Persero)
# 2     Staf Information Technology       PT Industri Kereta Api (Persero)
# 3    Staf Quality Control Testing       PT Industri Kereta Api (Persero)
# 4                 Staf Purchasing       PT Industri Kereta Api (Persero)
# ..                            ...                                    ...
# 307           Kerjasama Strategis      PT ASDP Indonesia Ferry (Persero)
# 308  Transaction Processing Staff  PT Bank Tabungan Negara (Persero) Tbk
# 309     Empty Cause Error Network              Empty Cause Error Network
# 310                  Loan Service  PT Bank Tabungan Negara (Persero) Tbk
# 311              Collective Staff  PT Bank Tabungan Negara (Persero) Tbk
#
#                                    Bidang                    Jenjang  \
# ...

# %%
df = df.replace('\n',' ', regex=True)
df = df.replace('Requirement:',' ', regex=True)

# data = df

# list(df['Title'].unique())

# %%
df
# Out:
#                            Posisi                             Perusahaan  \
# 0                  Staf Teknologi       PT Industri Kereta Api (Persero)
# 1         Staf Pengelolaan Proyek       PT Industri Kereta Api (Persero)
# 2     Staf Information Technology       PT Industri Kereta Api (Persero)
# 3    Staf Quality Control Testing       PT Industri Kereta Api (Persero)
# 4                 Staf Purchasing       PT Industri Kereta Api (Persero)
# ..                            ...                                    ...
# 307           Kerjasama Strategis      PT ASDP Indonesia Ferry (Persero)
# 308  Transaction Processing Staff  PT Bank Tabungan Negara (Persero) Tbk
# 309     Empty Cause Error Network              Empty Cause Error Network
# 310                  Loan Service  PT Bank Tabungan Negara (Persero) Tbk
# 311              Collective Staff  PT Bank Tabungan Negara (Persero) Tbk
#
#                                    Bidang                    Jenjang  \
# ...

# %%
df = df[df.Posisi != 'Empty Cause Error Network']

# %%
df
# Out:
#                            Posisi                             Perusahaan  \
# 0                  Staf Teknologi       PT Industri Kereta Api (Persero)
# 1         Staf Pengelolaan Proyek       PT Industri Kereta Api (Persero)
# 2     Staf Information Technology       PT Industri Kereta Api (Persero)
# 3    Staf Quality Control Testing       PT Industri Kereta Api (Persero)
# 4                 Staf Purchasing       PT Industri Kereta Api (Persero)
# ..                            ...                                    ...
# 306                    Sekretaris             PT RNI (Persero) - ID FOOD
# 307           Kerjasama Strategis      PT ASDP Indonesia Ferry (Persero)
# 308  Transaction Processing Staff  PT Bank Tabungan Negara (Persero) Tbk
# 310                  Loan Service  PT Bank Tabungan Negara (Persero) Tbk
# 311              Collective Staff  PT Bank Tabungan Negara (Persero) Tbk
#
#                                    Bidang                  Jenjang  \
# ...

# %%
df.isnull().sum()
# Out:
# Posisi         0
# Perusahaan     0
# Bidang         0
# Jenjang        0
# Jurusan        0
# Requirement    0
# Link           0
# dtype: int64

# %%
df
# Out:
#                            Posisi                             Perusahaan  \
# 0                  Staf Teknologi       PT Industri Kereta Api (Persero)
# 1         Staf Pengelolaan Proyek       PT Industri Kereta Api (Persero)
# 2     Staf Information Technology       PT Industri Kereta Api (Persero)
# 3    Staf Quality Control Testing       PT Industri Kereta Api (Persero)
# 4                 Staf Purchasing       PT Industri Kereta Api (Persero)
# ..                            ...                                    ...
# 306                    Sekretaris             PT RNI (Persero) - ID FOOD
# 307           Kerjasama Strategis      PT ASDP Indonesia Ferry (Persero)
# 308  Transaction Processing Staff  PT Bank Tabungan Negara (Persero) Tbk
# 310                  Loan Service  PT Bank Tabungan Negara (Persero) Tbk
# 311              Collective Staff  PT Bank Tabungan Negara (Persero) Tbk
#
#                                    Bidang                  Jenjang  \
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print('Counts for Job Title : \n',df['Posisi'].value_counts())

job_title_counts = df['Posisi'].value_counts()
# job_title_counts.to_csv('/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-JobTitle.csv', index=True, header=False)

fig, ax = plt.subplots()
fig.suptitle('Job Title', fontsize=12)

df['Posisi'].reset_index().groupby('Posisi').count().sort_values(by= 
       "index").plot(kind="barh", legend=False, 
        ax=ax)

plt.show()

# fig.savefig(f'/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-JobTitle.png', bbox_inches = 'tight')
# Out:
# Counts for Job Title :
#  Staff                           8
# Associate                       4
# Operator                        3
# Officer                         3
# Asisten Akuntansi & Keuangan    3
#                                ..
# Sales Consumer                  1
# Sekretaris Perusahaan           1
# Kepala Bagian SPI               1
# Kepala Urusan Aset              1
# Collective Staff                1
# Name: Posisi, Length: 218, dtype: int64

# %%
print('Top 20 Perusahaan yang Membuka Lowongan : \n',df['Perusahaan'].value_counts().head(20))

company_counts = df['Perusahaan'].value_counts().head(20)
# company_counts.to_csv('/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Company.csv', index=True, header=False)

Company = df.groupby(['Perusahaan']).count().sort_values('Posisi').tail(20)

Company['Posisi'].plot(kind='barh',figsize = (10,5))
plt.xlabel('Count', size=12)
plt.ylabel('')
plt.yticks(size = 10)
plt.xticks(size = 10)
plt.title('Top 20 Perusahaan yang Membuka Lowongan', size = 15)
# plt.savefig(f'/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Company.png', bbox_inches = 'tight')
plt.show()
# Out:
# Top 20 Perusahaan yang Membuka Lowongan :
#  PT Asabri (Persero)                                                                                                      11
# PT RNI (Persero) - ID FOOD - PT Garam                                                                                    10
# PT ASDP Indonesia Ferry (Persero)                                                                                        10
# Perum Perhutani                                                                                                          10
# PT RNI (Persero) - ID FOOD - PT Mitra Ogan                                                                                9
# PT Kereta Api Indonesia (Persero)                                                                                         8
# PT RNI (Persero) - ID FOOD - PT Perusahan Perdagangan Indonesia                                                           8
# ...

# %%
print('Counts for Indusatry : \n',df['Bidang'].value_counts().head(10))

Industry_counts = df['Bidang'].value_counts().head(10)
# Industry_counts.to_csv('/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Industry.csv', index=True, header=False)

Company = df.groupby(['Bidang']).count().sort_values('Posisi').tail(10)

Company['Posisi'].plot(kind='bar',figsize = (10,5))
plt.xlabel('')
plt.ylabel('Count', size = 12)
plt.yticks(size = 10)
plt.xticks(size = 10, rotation=45, ha='right')
plt.title('Number of Positions by Industry (Top 10)', size = 15)
# plt.savefig(f'/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Industry.png', bbox_inches = 'tight')

plt.show()
# Out:
# Counts for Industry :
#  Operasi / Produksi / Proyek             38
# Keuangan                                32
# Legal and Compliance                    29
# Engineering and Maintenance             27
# Bisnis Niaga / Pemasaran                22
# Digitalisasi and IT                     19
# Logistic / Supply Chain / Asset / GA    18
# SDM / HC                                15
# Analyst Research                        15
# Strategic Planning                      11
# Name: Bidang, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
print('Counts for Job Types : \n',df['Jenjang'].value_counts())

Types_counts = df['Jenjang'].value_counts()
# Types_counts.to_csv('/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Type.csv', index=True, header=False)

Company = df.groupby(['Jenjang']).count().sort_values('Posisi')

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:3]
labels = ['Sarjana S1 / Diploma IV', 'Diploma III', 'S2-Pascasarjana']

#create pie chart
plt.title('Jenjang Pendidikan', size = 15)
plt.pie(df['Jenjang'].value_counts(), colors = colors, autopct='%.2f%%')
plt.legend(labels, loc="lower left")
plt.savefig(f'/home/athoillah/Documents/FHCI/Jurusan.png', bbox_inches = 'tight')
plt.show()
# Out:
# Counts for Job Types :
#  Sarjana S1 / Diploma IV    226
# Diploma III                 31
# S2-Pasca Sarjana             1
# Name: Jenjang, dtype: int64

# %%
print('Counts for Level : \n',df['Level'].value_counts())

Level_counts = df['Level'].value_counts()
Level_counts.to_csv('/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Level.csv', index=True, header=False)

Company = df.groupby(['Level']).count().sort_values('Title')

Company['Title'].plot(kind='barh',figsize = (10,5))
plt.xlabel('Count', size = 12)
plt.ylabel('')
plt.yticks(size = 10)
plt.xticks(size = 10)
plt.title('Number of Positions by Level', size = 15)
plt.savefig(f'/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Level.png', bbox_inches = 'tight')
plt.show()
# Out:
# Counts for Level :
#  Entry level         329
# Mid-Senior level    269
# Associate           124
# Not Applicable       44
# Internship           14
# Director              8
# Executive             1
# Name: Level, dtype: int64

# %%
print('Counts for Job Locations : \n',df['Location'].value_counts().head(20))

Location_counts = df['Location'].value_counts().head(20)
Location_counts.to_csv('/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Location.csv', index=True, header=False)

Company = df.groupby(['Location']).count().sort_values('Title').tail(20)

Company['Title'].plot(kind='bar',figsize = (10,5))
plt.xlabel('Location', size = 12)
plt.ylabel('Count', size = 12)
plt.yticks(size = 10)
plt.xticks(size = 10, rotation=45, ha='right')
plt.title('Number of Positions by Location', size = 15)
plt.savefig(f'/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Location.png', bbox_inches = 'tight')
plt.show()
# Out:
# Counts for Job Locations :
#  Jakarta       575
# Indonesia      76
# Bandung        31
# Tangerang      29
# Yogyakarta     17
# Bali           12
# Surabaya       11
# Pontianak       7
# Papua           7
# Kupang          4
# Depok           3
# Malang          2
# Sidoarjo        2
# Semarang        2
# Medan           2
# Bogor           2
# Mataram         1
# Lampung         1
# Bekasi          1
# Surakarta       1
# Name: Location, dtype: int64

# %%
df
# Out:
#            Date                                   Company  \
# 0    2022-11-07                  PT Smartfren Telecom Tbk
# 1    2022-11-11                         Alterra Indonesia
# 2    2022-11-05  PT Bank Multiarta Sentosa Tbk (Bank MAS)
# 3    2022-11-02                           Astra Financial
# 4    2022-11-02                           Astra Financial
# ..          ...                                       ...
# 991  2022-11-22                                   NTT ltd
# 992  2022-10-28                              MatchaTalent
# 993  2022-10-18                             Packet System
# 997  2022-10-24                                       ION
# 998  2022-11-24                                     Agoda
#
#                          Title   Location  \
# 0                Data Engineer  Tangerang
# 1                Data Engineer    Jakarta
# 2                Data Engineer    Jakarta
# 3                Data Engineer    Jakarta
# 4                 Data Analyst    Jakarta
# ...

# %%
import datetime

df.Date = pd.to_datetime(df.Date)

print("Big Query Statistics:")
print("---------------------")
print(f"🚣‍♀️Rows of data: {len(df)}")

first_date = df.Date.dt.date.min()
today_date = datetime.date.today() #+ datetime.timedelta(days=2) # test function works
date_count = pd.DataFrame(df.Date.dt.date.value_counts())
missing_dates = list(pd.date_range(start=first_date, end=today_date).difference(date_count.index))
# if len(missing_dates) > 0:
#     print("❌ Missing data for following dates:")
#     for date in missing_dates:
#         print(date)
# else:
#     print(f"✅ No missing dates of data since inception of: {first_date}")

delta_days = (today_date - (first_date - datetime.timedelta(days=2))).days # first day was actually day prior but UTC
jobs_day = round(len(df)/delta_days)
print(f"🧑‍💻 Average number of jobs per day: {jobs_day}")
print(f"📆 Collecting data for {delta_days} days now...")
# Out:
# Big Query Statistics:
# ---------------------
# 🚣‍♀️Rows of data: 789
# 🧑‍💻 Average number of jobs per day: 2
# 📆 Collecting data for 379 days now...

# %%
from nltk.tokenize import word_tokenize, MWETokenizer

# Picked out keywords based on all keywords (only looked words with 100+ occurrences)
keywords_programming = [
'sql', 'python', 'r', 'c', 'c#', 'javascript', 'js',  'java', 'scala', 'sas', 'matlab', 
'c++', 'c/c++', 'perl', 'go', 'typescript', 'bash', 'html', 'css', 'php', 'powershell', 'rust', 
'kotlin', 'ruby',  'dart', 'assembly', 'swift', 'vba', 'lua', 'groovy', 'delphi', 'objective-c', 
'haskell', 'elixir', 'julia', 'clojure', 'solidity', 'lisp', 'f#', 'fortran', 'erlang', 'apl', 
'cobol', 'ocaml', 'crystal', 'javascript/typescript', 'golang', 'nosql', 'mongodb', 't-sql', 'no-sql',
'visual_basic', 'pascal', 'mongo', 'pl/sql',  'sass', 'vb.net', 'mssql', 
]

keywords_libraries = [
'scikit-learn', 'jupyter', 'theano', 'openCV', 'spark', 'nltk', 'mlpack', 'chainer', 'fann', 'shogun', 
'dlib', 'mxnet', 'node.js', 'vue', 'vue.js', 'keras', 'ember.js', 'jse/jee',
]

keywords_analyst_tools = [
'excel', 'tableau',  'word', 'powerpoint', 'looker', 'powerbi', 'outlook', 'azure', 'jira', 'twilio',  'snowflake', 
'shell', 'linux', 'sas', 'sharepoint', 'mysql', 'visio', 'git', 'mssql', 'powerpoints', 'postgresql', 'spreadsheets',
'seaborn', 'pandas', 'gdpr', 'spreadsheet', 'alteryx', 'github', 'postgres', 'ssis', 'numpy', 'power_bi', 'spss', 'ssrs', 
'microstrategy',  'cognos', 'dax', 'matplotlib', 'dplyr', 'tidyr', 'ggplot2', 'plotly', 'esquisse', 'rshiny', 'mlr',
'docker', 'linux', 'jira',  'hadoop', 'airflow', 'redis', 'graphql', 'sap', 'tensorflow', 'node', 'asp.net', 'unix',
'jquery', 'pyspark', 'pytorch', 'gitlab', 'selenium', 'splunk', 'bitbucket', 'qlik', 'terminal', 'atlassian', 'unix/linux',
'linux/unix', 'ubuntu', 'nuix', 'datarobot',
]

keywords_cloud_tools = [
'aws', 'azure', 'gcp', 'snowflake', 'redshift', 'bigquery', 'aurora',
]

# Not using
keywords_general_tools = [
'microsoft', 'slack', 'apache', 'ibm', 'html5', 'datadog', 'bloomberg',  'ajax', 'persicope', 'oracle', 
]

# Not using
keywords_general = [
'coding', 'server', 'database', 'cloud', 'warehousing', 'scrum', 'devops', 'programming', 'saas', 'ci/cd', 'cicd', 
'ml', 'data_lake', 'frontend',' front-end', 'back-end', 'backend', 'json', 'xml', 'ios', 'kanban', 'nlp',
'iot', 'codebase', 'agile/scrum', 'agile', 'ai/ml', 'ai', 'paas', 'machine_learning', 'macros', 'iaas',
'fullstack', 'dataops', 'scrum/agile', 'ssas', 'mlops', 'debug', 'etl', 'a/b', 'slack', 'erp', 'oop', 
'object-oriented', 'etl/elt', 'elt', 'dashboarding', 'big-data', 'twilio', 'ui/ux', 'ux/ui', 'vlookup', 
'crossover',  'data_lake', 'data_lakes', 'bi', 
]

keywords = keywords_programming + keywords_libraries + keywords_analyst_tools + keywords_cloud_tools 

df = df[df.Description.notnull()] # filter out null values
df = df.reset_index() # throwing index issues if don't reset index
# jobs_all = jobs_all.head(10) 

df['Description_tokens'] = ""
for index, row in df.iterrows():
    # lowercase words
    detail = row.Description.lower()
    # tokenize words
    detail = word_tokenize(detail)
    # handle multi-word tokenization (e.g., 'Power BI')
    multi_tokens = [('power', 'bi'), ('data', 'lake'), ('data', 'lakes'), ('machine', 'learning'), ('objective', 'c'),
                    ('visual', 'basic')]
    tokenizer = MWETokenizer(multi_tokens)
    detail = tokenizer.tokenize(detail)
    # remove duplicates
    detail = list(set(detail))
    # filter for keywords only
    detail = [word for word in detail if word in keywords] 
    # replace duplicate keywords
    replace_tokens = {'powerbi' : 'power_bi', 'spreadsheets': 'spreadsheet'}
    for key, value in replace_tokens.items():
        detail = [d.replace(key, value) for d in detail]
    # add to details list # row.description_tokens = detail
    df.at[index, 'Description_tokens'] = detail

# %%
import numpy as np
def filtered_keywords(df, keywords, title="Keyword Analysis", filename=None, save=None, head=10):
    # get keywords in a column
    count_keywords = pd.DataFrame(df.Description_tokens.sum()).value_counts().rename_axis('keywords').reset_index(name='counts')

    # get frequency of occurence of word (as word only appears once per line)
    length = len(df) # number of job postings
    count_keywords['percentage'] = 100 * count_keywords.counts / length

    # plot the results
    count_keywords = count_keywords[count_keywords.keywords.isin(keywords)]
    count_keywords = count_keywords.head(head)
    g = plt.bar(x="keywords", height="percentage", data=count_keywords , color=np.random.rand(len(count_keywords.keywords), 3))
    plt.xlabel("")
    plt.ylabel("Likelyhood to be in job posting (%)")
    plt.xticks(rotation = 45, ha='right')
    plt.title(title)
    filename = filename if filename else f'{keywords}.png'
    plt.savefig(f'/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/{filename}', bbox_inches = 'tight')
    plt.show(g)
    
    save = save if save else f'{keywords}.csv'
    count_keywords.to_csv(f'/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/{save}.csv', index=False)
    print(count_keywords)

# %%
filtered_keywords(df, keywords_programming, title="Top Programming Languages for Data Engineer Linkedin Search", filename='Likelyhood_Languages', save='Likelyhood_Languages')
# Out:
#       keywords  counts  percentage
# 0          sql      46    5.830165
# 1       python      45    5.703422
# 2         java      40    5.069708
# 4          c++      20    2.534854
# 6         perl      14    1.774398
# 7           go      14    1.774398
# 9   javascript      12    1.520913
# 12        ruby      11    1.394170
# 17           r       8    1.013942
# 24     mongodb       6    0.760456

# %%
filtered_keywords(df, keywords, title="Top Tools for Data Engineer Linkedin Search", filename='Likelyhood_Tools', save='Likelyhood_Tools')
# Out:
#      keywords  counts  percentage
# 0         sql      46    5.830165
# 1      python      45    5.703422
# 2        java      40    5.069708
# 3         aws      30    3.802281
# 4         c++      20    2.534854
# 5       linux      16    2.027883
# 6        perl      14    1.774398
# 7          go      14    1.774398
# 8       azure      12    1.520913
# 9  javascript      12    1.520913

# %%
from fpdf import FPDF
from datetime import datetime, date
import csv



WIDTH = 210
HEIGHT = 297

TEST_DATE = "30/11/22"

def create_title(day, pdf, section=None,):
    pdf.set_font('Arial', '', 24)  
    pdf.ln(45)
    pdf.write(5, f"{section} Report")
    pdf.ln(10)
    pdf.set_font('Arial', '', 16)
    pdf.write(4, f'{day}')
    pdf.ln(5)

def create_analytics_report(day=TEST_DATE, filename="Report-All-Data.pdf"):
    pdf = FPDF() 

    ''' First Page '''
    pdf.add_page()
    
    pdf.image("/home/athoillah/Documents/Local_Linkedin_Pipeline/Report/Letterhead/All-Data.png", 0, 0, WIDTH)

    ''' Second Page '''
    pdf.add_page()
    pdf.image("/home/athoillah/Documents/Local_Linkedin_Pipeline/Report/Letterhead/Backgroud.png", 0, 0, WIDTH)
    create_title(day,pdf,section='Job Title')
    pdf.image("/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-JobTitle.png", 5, 80, WIDTH-20)
    
    pdf.ln(150)
    
    pdf.set_font('Courier', '', 10)
    col_width = WIDTH/2
    th = pdf.font_size

    with open('/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-JobTitle.csv', newline='') as f:
        reader = csv.reader(f)

        for row in reader:
            pdf.cell(col_width, th, str(row[0]), border=0)
            pdf.cell(col_width, th, row[1], border=0)
            pdf.ln(th)
    
    
    ''' Third Page '''
    pdf.add_page()
    pdf.image("/home/athoillah/Documents/Local_Linkedin_Pipeline/Report/Letterhead/Backgroud.png", 0, 0, WIDTH)
    create_title(day,pdf,section='Top Company')
    pdf.image("/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Company.png", 5, 80, WIDTH-20)
    
    pdf.ln(135)
    
    pdf.set_font('Courier', '', 10)
    col_width = WIDTH/2
    th = pdf.font_size

    with open('/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Company.csv', newline='') as f:
        reader = csv.reader(f)

        for row in reader:
            pdf.cell(col_width, th, str(row[0]), border=0)
            pdf.cell(col_width, th, row[1], border=0)
            pdf.ln(th)
    
    ''' Fourth Page '''
    pdf.add_page()
    pdf.image("/home/athoillah/Documents/Local_Linkedin_Pipeline/Report/Letterhead/Backgroud.png", 0, 0, WIDTH)
    create_title(day,pdf,section='Top Industry Types')
    pdf.image("/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Industry.png", 5, 80, WIDTH-20)
    
    pdf.ln(150)
    
    pdf.set_font('Courier', '', 10)
    col_width = WIDTH/1.5
    th = pdf.font_size

    with open('/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Industry.csv', newline='') as f:
        reader = csv.reader(f)

        for row in reader:
            pdf.cell(col_width, th, str(row[0]), border=0)
            pdf.cell(col_width, th, row[1], border=0)
            pdf.ln(th)
    
    ''' Fifth Page '''
    pdf.add_page()
    pdf.image("/home/athoillah/Documents/Local_Linkedin_Pipeline/Report/Letterhead/Backgroud.png", 0, 0, WIDTH)
    create_title(day,pdf,section='Count of Level Types')
    pdf.image("/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Level.png", 5, 80, WIDTH-20)
    
    pdf.ln(120)
    
    pdf.set_font('Courier', '', 10)
    col_width = WIDTH/2
    th = pdf.font_size

    with open('/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Level.csv', newline='') as f:
        reader = csv.reader(f)

        for row in reader:
            pdf.cell(col_width, th, str(row[0]), border=0)
            pdf.cell(col_width, th, row[1], border=0)
            pdf.ln(th)
    
    ''' Sixth Page '''
    pdf.add_page()
    pdf.image("/home/athoillah/Documents/Local_Linkedin_Pipeline/Report/Letterhead/Backgroud.png", 0, 0, WIDTH)
    create_title(day,pdf,section='Count of Working Types')
    pdf.image("/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Types.png", 5, 80, WIDTH-20)
    
    pdf.ln(120)
    
    pdf.set_font('Courier', '', 10)
    col_width = WIDTH/2
    th = pdf.font_size

    with open('/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Type.csv', newline='') as f:
        reader = csv.reader(f)

        for row in reader:
            pdf.cell(col_width, th, str(row[0]), border=0)
            pdf.cell(col_width, th, row[1], border=0)
            pdf.ln(th)
    
    ''' Seventh Page '''
    pdf.add_page()
    pdf.image("/home/athoillah/Documents/Local_Linkedin_Pipeline/Report/Letterhead/Backgroud.png", 0, 0, WIDTH)
    create_title(day,pdf,section='Job Offered Locations')
    pdf.image("/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Location.png", 5, 80, WIDTH-20)
    
    pdf.ln(130)
    
    pdf.set_font('Courier', '', 10)
    col_width = WIDTH/2
    th = pdf.font_size

    with open('/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/AllData-Location.csv', newline='') as f:
        reader = csv.reader(f)

        for row in reader:
            pdf.cell(col_width, th, str(row[0]), border=0)
            pdf.cell(col_width, th, row[1], border=0)
            pdf.ln(th)
    
    ''' Eigth Page '''
    pdf.add_page()
    pdf.image("/home/athoillah/Documents/Local_Linkedin_Pipeline/Report/Letterhead/Backgroud.png", 0, 0, WIDTH)
    create_title(day,pdf,section='Likelyhood Programming Language')
    pdf.image("/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/Likelyhood_Languages.png", 5, 80, WIDTH-20)
    pdf.ln(167)
    pdf.set_font('Courier', '', 10)
    col_width = WIDTH/3
    th = pdf.font_size

    with open('/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/Likelyhood_Languages.csv', newline='') as f:
        reader = csv.reader(f)
        
        for row in reader:
            pdf.cell(col_width, th, str(row[0]), border=0)
            pdf.cell(col_width, th, row[1], border=0)
            pdf.cell(col_width, th, row[2], border=0)
            pdf.ln(th)
    
    ''' Nineth Page '''
    pdf.add_page()
    pdf.image("/home/athoillah/Documents/Local_Linkedin_Pipeline/Report/Letterhead/Backgroud.png", 0, 0, WIDTH)
    create_title(day,pdf,section='Likelyhood Programming Tools')
    pdf.image("/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/Likelyhood_Tools.png", 5, 75, WIDTH-20)
    
    pdf.ln(167)
    
    pdf.set_font('Courier', '', 10)
    col_width = WIDTH/3
    th = pdf.font_size
    

    with open('/home/athoillah/Documents/Local_Linkedin_Pipeline/Image-Output/AllData/Likelyhood_Tools.csv', newline='') as f:
        reader = csv.reader(f)
        
        for row in reader:
            pdf.cell(col_width, th, str(row[0]), border=0)
            pdf.cell(col_width, th, row[1], border=0)
            pdf.cell(col_width, th, row[2], border=0)
            pdf.ln(th)
    
    pdf.output(f"/home/athoillah/Documents/Local_Linkedin_Pipeline/Report/{filename}", 'F')

# %%
today = date.today()
create_analytics_report(today)

# %%
# webhook_url = 'https://discord.com/api/webhooks/1047180196370984990/-v_JzeRfV59hObja8JpL9s8kpLsUxRKrfsMlkb3Opm1QHL6UvUbs3xbSYx0FBoDuRmn7'
# filename = 'All-Data'
# output_file = f"/home/athoillah/Documents/Local_Linkedin_Pipeline/Report/Report-{filename}.pdf"

def send_to_discord(filename=None):
    import discord
    from datetime import datetime, date
    today = date.today()
    webhook_url = 'https://discord.com/api/webhooks/1047180196370984990/-v_JzeRfV59hObja8JpL9s8kpLsUxRKrfsMlkb3Opm1QHL6UvUbs3xbSYx0FBoDuRmn7'
    output_file = f"/home/athoillah/Documents/Local_Linkedin_Pipeline/Report/Report-{filename}.pdf"
    from discord import SyncWebhook

    webhook = SyncWebhook.from_url(webhook_url)
    
    pdf_file = discord.File(output_file)
    
    webhook.send(f'This is An Automated Report from Linkedin Analysis on {today}', 
                username='Reporting-Worker', 
                file=pdf_file)

# %%
send_to_discord(filename='All-Data')
